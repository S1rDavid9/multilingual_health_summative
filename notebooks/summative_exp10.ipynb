# %% [markdown]
# # Experiment 10 — Hybrid Semantic + TF-IDF Retrieval
#
# **Approach:** Combine semantic embeddings (sentence transformers) with TF-IDF keyword matching for retrieval. For each language subset, the final score is a weighted combination:
#
# ```
# score = tfidf_weight * tfidf_score + semantic_weight * semantic_score
# ```
#
# **Why hybrid?** Semantic retrieval understands meaning but can miss exact keyword matches. TF-IDF catches exact matches but misses paraphrases. Combining both gives better coverage across all languages.
#
# **Expected runtime:** 30–50 minutes on Colab.

# %% [markdown]
# ## 1 — Install and Import Packages

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# !pip install -q scikit-learn pandas numpy rouge-score
# !pip install -q sentence-transformers

print('✅ Packages installed')
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for rouge-score (setup.py) ... done
# ✅ Packages installed

# %%
import re
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import torch

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

warnings.filterwarnings('ignore')

SEED = 42
print('✅ Imports done')
# Out:
# ✅ Imports done

# %% [markdown]
# ## 2 — Set File Paths

# %%
DATA_DIR = Path('/content')

TRAIN_PATH      = DATA_DIR / 'Train.csv'
TEST_PATH       = DATA_DIR / 'Test.csv'
VAL_PATH        = DATA_DIR / 'Val.csv'
SAMPLE_SUB_PATH = DATA_DIR / 'SampleSubmission.csv'

OUTPUT_EXP10 = Path('/content/submission_exp10_hybrid.csv')

for path in [TRAIN_PATH, TEST_PATH, VAL_PATH, SAMPLE_SUB_PATH]:
    status = '✅' if path.exists() else '❌'
    print(f'{status} {path}')
# Out:
# ✅ /content/Train.csv
# ✅ /content/Test.csv
# ✅ /content/Val.csv
# ✅ /content/SampleSubmission.csv

# %% [markdown]
# ## 3 — Load Data

# %%
train             = pd.read_csv(TRAIN_PATH)
test              = pd.read_csv(TEST_PATH)
val               = pd.read_csv(VAL_PATH)
sample_submission = pd.read_csv(SAMPLE_SUB_PATH)

print(f'Train shape : {train.shape}')
print(f'Test shape  : {test.shape}')
print(f'Val shape   : {val.shape}')

print('\nLanguage distribution in training set:')
display(train['subset'].value_counts())
# Out:
# Train shape : (29815, 4)
# Test shape  : (2618, 3)
# Val shape   : (6686, 4)
#
# Language distribution in training set:
# subset
# Eng_Uga    7624
# Aka_Gha    4455
# Eng_Gha    4443
# Eng_Eth    3915
# Lug_Uga    3383
# Eng_Ken    2080
# Swa_Ken    2070
# Amh_Eth    1845
# Name: count, dtype: int64

# %% [markdown]
# ## 4 — Column Configuration

# %%
ID_COL            = 'ID'
TEST_ID_COL       = 'ID'
QUESTION_COL      = 'input'
TEST_QUESTION_COL = 'input'
ANSWER_COL        = 'output'
LANG_COL          = 'subset'
TEST_LANG_COL     = 'subset'

# Semantic model
SEMANTIC_MODEL_NAME = 'paraphrase-multilingual-MiniLM-L12-v2'
SEMANTIC_BATCH_SIZE = 256

# Hybrid weights per language subset
# (method, tfidf_weight, semantic_weight)
# Tuned: English subsets benefit from more TF-IDF (exact match)
# Non-Latin scripts (Amharic, Luganda) benefit from more semantic
LANGUAGE_STRATEGY = {
    'Aka_Gha': ('hybrid', 0.4, 0.6),
    'Amh_Eth': ('hybrid', 0.2, 0.8),
    'Eng_Eth': ('hybrid', 0.5, 0.5),
    'Eng_Gha': ('hybrid', 0.5, 0.5),
    'Eng_Ken': ('hybrid', 0.5, 0.5),
    'Eng_Uga': ('hybrid', 0.5, 0.5),
    'Lug_Uga': ('hybrid', 0.3, 0.7),
    'Swa_Ken': ('hybrid', 0.4, 0.6),
}

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Device : {DEVICE}')
print(f'Model  : {SEMANTIC_MODEL_NAME}')
# Out:
# Device : cpu
# Model  : paraphrase-multilingual-MiniLM-L12-v2

# %% [markdown]
# ## 5 — Text Cleaning

# %%
def clean_text(x):
    if pd.isna(x):
        return ''
    return str(x).strip()

train[QUESTION_COL]      = train[QUESTION_COL].map(clean_text)
train[ANSWER_COL]        = train[ANSWER_COL].map(clean_text)
test[TEST_QUESTION_COL]  = test[TEST_QUESTION_COL].map(clean_text)
val[QUESTION_COL]        = val[QUESTION_COL].map(clean_text)
val[ANSWER_COL]          = val[ANSWER_COL].map(clean_text)

print('✅ Text cleaned')
# Out:
# ✅ Text cleaned

# %% [markdown]
# ## 6 — ROUGE Evaluation

# %%
try:
    from rouge_score import rouge_scorer

    class WhitespaceTokenizer:
        def tokenize(self, text):
            if text is None:
                return []
            return str(text).strip().split()

    _scorer = rouge_scorer.RougeScorer(
        ['rouge1', 'rougeL'],
        tokenizer=WhitespaceTokenizer()
    )

    def compute_rouge(predictions, references):
        r1_scores, rl_scores = [], []
        for pred, ref in zip(predictions, references):
            scores = _scorer.score(str(ref), str(pred))
            r1_scores.append(scores['rouge1'].fmeasure)
            rl_scores.append(scores['rougeL'].fmeasure)
        return {
            'rouge1_f1': float(np.mean(r1_scores)),
            'rougeL_f1': float(np.mean(rl_scores)),
        }

    def compute_rouge_by_language(predictions, references, languages):
        rows = []
        for lang in sorted(set(languages)):
            idx = [i for i, l in enumerate(languages) if l == lang]
            preds_l = [predictions[i] for i in idx]
            refs_l  = [references[i]  for i in idx]
            m = compute_rouge(preds_l, refs_l)
            rows.append({'language': lang, 'rouge1_f1': m['rouge1_f1'], 'rougeL_f1': m['rougeL_f1']})
        return pd.DataFrame(rows).set_index('language')

    print('✅ ROUGE scoring available')
    compute_rouge_available = True

except Exception as e:
    print(f'⚠️  ROUGE unavailable: {e}')
    compute_rouge_available = False
    compute_rouge = None
# Out:
# ✅ ROUGE scoring available

# %% [markdown]
# ## 7 — Hybrid Retrieval Index

# %%
def _minmax_scores(scores):
    scores = np.asarray(scores, dtype=float)
    lo, hi = scores.min(), scores.max()
    if hi - lo < 1e-9:
        return np.ones_like(scores)
    return (scores - lo) / (hi - lo)


class HybridRetrievalIndex:
    """
    Hybrid retrieval combining semantic embeddings and TF-IDF.
    Per-language subset weights control the blend.
    """

    def __init__(
        self,
        model_name=SEMANTIC_MODEL_NAME,
        batch_size=SEMANTIC_BATCH_SIZE,
        language_strategy=None,
    ):
        self.model_name        = model_name
        self.batch_size        = batch_size
        self.language_strategy = language_strategy or LANGUAGE_STRATEGY
        self.encoder           = None
        self.questions         = []
        self.answers           = []
        self.embeddings        = None
        self.subset_indices    = {}
        self.subset_tfidf      = {}

    def _get_encoder(self):
        if self.encoder is None:
            print(f'  Loading encoder: {self.model_name} ({DEVICE})')
            self.encoder = SentenceTransformer(self.model_name, device=DEVICE)
        return self.encoder

    def _encode(self, texts):
        encoder = self._get_encoder()
        parts = []
        for start in range(0, len(texts), self.batch_size):
            end = min(start + self.batch_size, len(texts))
            parts.append(
                encoder.encode(texts[start:end], show_progress_bar=False, normalize_embeddings=True)
            )
            if end % 5000 == 0 or end == len(texts):
                print(f'    Encoded {end:,} / {len(texts):,}')
        return np.vstack(parts)

    def fit(self, df, question_col, answer_col, lang_col):
        self.questions = df[question_col].fillna('').astype(str).tolist()
        self.answers   = df[answer_col].fillna('').astype(str).tolist()

        print(f'  Encoding {len(self.questions):,} training questions...')
        self.embeddings = self._encode(self.questions)

        for subset in df[lang_col].unique():
            mask    = df[lang_col] == subset
            indices = np.where(mask.values)[0]
            self.subset_indices[subset] = indices

            subset_questions = [self.questions[i] for i in indices]
            vectorizer = TfidfVectorizer(ngram_range=(1, 2), max_features=100_000)
            matrix = vectorizer.fit_transform(subset_questions)
            self.subset_tfidf[subset] = {'vectorizer': vectorizer, 'matrix': matrix}

        print(f'  ✅ Index built: {len(self.questions):,} questions, {len(self.subset_indices)} subsets')
        return self

    def retrieve_one(self, question, question_embedding, subset):
        if subset not in self.subset_indices:
            subset = next(iter(self.subset_indices))

        indices = self.subset_indices[subset]
        method, tfidf_w, semantic_w = self.language_strategy.get(subset, ('hybrid', 0.4, 0.6))

        candidate_embeddings = self.embeddings[indices]
        semantic_scores = cosine_similarity(
            question_embedding.reshape(1, -1), candidate_embeddings
        ).flatten()

        if method == 'semantic' or tfidf_w == 0.0:
            best = int(indices[int(np.argmax(semantic_scores))])
            return self.answers[best]

        subset_info  = self.subset_tfidf[subset]
        query_tfidf  = subset_info['vectorizer'].transform([question])
        tfidf_scores = cosine_similarity(query_tfidf, subset_info['matrix']).flatten()

        # Normalize both score distributions before combining
        semantic_scores = _minmax_scores(semantic_scores)
        tfidf_scores    = _minmax_scores(tfidf_scores)

        hybrid_scores = tfidf_w * tfidf_scores + semantic_w * semantic_scores
        best = int(indices[int(np.argmax(hybrid_scores))])
        return self.answers[best]

    def predict(self, df, question_col, lang_col):
        questions = df[question_col].fillna('').astype(str).tolist()
        subsets   = df[lang_col].tolist()

        print(f'  Encoding {len(questions):,} query questions...')
        query_embeddings = self._encode(questions)

        predictions = []
        for i, (q, emb, subset) in enumerate(zip(questions, query_embeddings, subsets)):
            predictions.append(self.retrieve_one(q, emb, subset))
            if (i + 1) % 500 == 0 or (i + 1) == len(questions):
                print(f'  Retrieved {i + 1:,} / {len(questions):,}')

        return predictions

print('✅ HybridRetrievalIndex defined')
# Out:
# ✅ HybridRetrievalIndex defined

# %% [markdown]
# ## 8 — Validate on Val Set

# %%
print('Building hybrid index on training data...')
index_val = HybridRetrievalIndex().fit(train, QUESTION_COL, ANSWER_COL, LANG_COL)

# Sample 500 for speed
val_sample = val.sample(n=500, random_state=SEED)
print(f'\nPredicting on {len(val_sample)} validation examples...')
val_preds = index_val.predict(val_sample, QUESTION_COL, LANG_COL)
val_refs  = val_sample[ANSWER_COL].tolist()

if compute_rouge_available:
    metrics = compute_rouge(val_preds, val_refs)
    print(f'\n📊 Exp 10 — Hybrid Retrieval — Validation ROUGE')
    print(f'   ROUGE-1 F1 : {metrics["rouge1_f1"]:.4f}')
    print(f'   ROUGE-L F1 : {metrics["rougeL_f1"]:.4f}')

    print('\n📊 ROUGE by language:')
    lang_metrics = compute_rouge_by_language(val_preds, val_refs, val_sample[LANG_COL].tolist())
    display(lang_metrics.round(4))
# Out:
# Building hybrid index on training data...
#   Encoding 29,815 training questions...
#   Loading encoder: paraphrase-multilingual-MiniLM-L12-v2 (cpu)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/526 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#     Encoded 29,815 / 29,815
#   ✅ Index built: 29,815 questions, 8 subsets
#
# Predicting on 500 validation examples...
#   Encoding 500 query questions...
#     Encoded 500 / 500
#   Retrieved 500 / 500
#
# 📊 Exp 10 — Hybrid Retrieval — Validation ROUGE
#    ROUGE-1 F1 : 0.4088
#    ROUGE-L F1 : 0.3541
#
# 📊 ROUGE by language:
#           rouge1_f1  rougeL_f1
# language
# Aka_Gha      0.2962     0.1818
# Amh_Eth      0.1043     0.0984
# Eng_Eth      0.5218     0.5038
# Eng_Gha      0.2636     0.1737
# Eng_Ken      0.7166     0.6918
# Eng_Uga      0.5180     0.4675
# Lug_Uga      0.4299     0.4002
# Swa_Ken      0.5958     0.5629
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %% [markdown]
# ## 9 — Generate Test Predictions

# %%
# Fit on train + val combined for best coverage
corpus = pd.concat([train, val], ignore_index=True)
print(f'Building final index on {len(corpus):,} examples (train + val)...')
index_test = HybridRetrievalIndex().fit(corpus, QUESTION_COL, ANSWER_COL, LANG_COL)

print(f'\nPredicting on {len(test):,} test questions...')
test_preds = index_test.predict(test, TEST_QUESTION_COL, TEST_LANG_COL)

print(f'\n✅ Generated {len(test_preds):,} answers')

# Preview
preview = test[[TEST_ID_COL, TEST_QUESTION_COL]].copy()
preview['predicted_answer'] = test_preds
display(preview.head(5))
# Out:
# Building final index on 36,501 examples (train + val)...
#   Encoding 36,501 training questions...
#   Loading encoder: paraphrase-multilingual-MiniLM-L12-v2 (cpu)
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
#     Encoded 36,501 / 36,501
#   ✅ Index built: 36,501 questions, 8 subsets
#
# Predicting on 2,618 test questions...
#   Encoding 2,618 query questions...
#     Encoded 2,618 / 2,618
#   Retrieved 500 / 2,618
#   Retrieved 1,000 / 2,618
#   Retrieved 1,500 / 2,618
#   Retrieved 2,000 / 2,618
#   Retrieved 2,500 / 2,618
#   Retrieved 2,618 / 2,618
#
# ✅ Generated 2,618 answers
#                        ID                                              input  \
# 0  ID_TS_Aka_Gha_A3B1799D  Fa nneɛma a wɔde bɛyɛ nkyerɛkyerɛ nneɛma, adwu...
# 1  ID_TS_Aka_Gha_1C80317F  Dɛn ne nea ebetumi afi hokwan a mmabun wɔ sɛ w...
# 2  ID_TS_Aka_Gha_06671AD1  Akwan bɛn na mmabun bɛtumi afa so ehunu nsusua...
# 3  ID_TS_Aka_Gha_BDD640FB  Sɛnea amammerɛ mu mmra, asetena mu suban, ne t...
# 4  ID_TS_Aka_Gha_46685257  Adɛn nti na mmara nsesaeɛ 'policy advocacy' ho...
#
#                                     predicted_answer
# 0  Atuhoama: Ahyehyɛde pii gye atuhoamafo akwaaba...
# 1  Ahintasɛm a wobu so betumi de ɔhaw kɛse aba mm...
# 2  Mmabun betumi de akwan horow adi dwuma de wɔn ...
# 3  Mmabun adwumayɛ ho nhyehyɛe ahorow: Ɔsatu ahor...
# 4  Ɛma wosusuw nsɛm ho ansa na woayi bi. Nsɛm a ɛ...

# %% [markdown]
# ## 10 — Save Submission

# %%
def make_submission(ids, predictions, output_path):
    cleaned = [
        re.sub(r'\s+', ' ', str(p)).strip() if p else 'no answer'
        for p in predictions
    ]
    sub = pd.DataFrame({
        'ID'        : ids,
        'TargetRLF1': cleaned,
        'TargetR1F1': cleaned,
        'TargetLLM' : cleaned,
    })
    sub.to_csv(output_path, index=False)
    print(f'✅ Submission saved to: {output_path}')
    print(f'   Shape : {sub.shape}')
    display(sub.head())
    return sub

make_submission(
    ids         = test[TEST_ID_COL].values,
    predictions = test_preds,
    output_path = OUTPUT_EXP10,
)
# Out:
# ✅ Submission saved to: /content/submission_exp10_hybrid.csv
#    Shape : (2618, 4)
#                        ID                                         TargetRLF1  \
# 0  ID_TS_Aka_Gha_A3B1799D  Atuhoama: Ahyehyɛde pii gye atuhoamafo akwaaba...
# 1  ID_TS_Aka_Gha_1C80317F  Ahintasɛm a wobu so betumi de ɔhaw kɛse aba mm...
# 2  ID_TS_Aka_Gha_06671AD1  Mmabun betumi de akwan horow adi dwuma de wɔn ...
# 3  ID_TS_Aka_Gha_BDD640FB  Mmabun adwumayɛ ho nhyehyɛe ahorow: Ɔsatu ahor...
# 4  ID_TS_Aka_Gha_46685257  Ɛma wosusuw nsɛm ho ansa na woayi bi. Nsɛm a ɛ...
#
#                                           TargetR1F1  \
# 0  Atuhoama: Ahyehyɛde pii gye atuhoamafo akwaaba...
# 1  Ahintasɛm a wobu so betumi de ɔhaw kɛse aba mm...
# 2  Mmabun betumi de akwan horow adi dwuma de wɔn ...
# 3  Mmabun adwumayɛ ho nhyehyɛe ahorow: Ɔsatu ahor...
# 4  Ɛma wosusuw nsɛm ho ansa na woayi bi. Nsɛm a ɛ...
#
#                                            TargetLLM
# 0  Atuhoama: Ahyehyɛde pii gye atuhoamafo akwaaba...
# 1  Ahintasɛm a wobu so betumi de ɔhaw kɛse aba mm...
# 2  Mmabun betumi de akwan horow adi dwuma de wɔn ...
# 3  Mmabun adwumayɛ ho nhyehyɛe ahorow: Ɔsatu ahor...
# 4  Ɛma wosusuw nsɛm ho ansa na woayi bi. Nsɛm a ɛ...
#                           ID  \
# 0     ID_TS_Aka_Gha_A3B1799D
# 1     ID_TS_Aka_Gha_1C80317F
# 2     ID_TS_Aka_Gha_06671AD1
# 3     ID_TS_Aka_Gha_BDD640FB
# 4     ID_TS_Aka_Gha_46685257
# ...                      ...
# 2613  ID_TS_Swa_Ken_C9525185
# 2614  ID_TS_Swa_Ken_FD034ADA
# 2615  ID_TS_Swa_Ken_81F38DD4
# 2616  ID_TS_Swa_Ken_8DDCE719
# 2617  ID_TS_Swa_Ken_0534A101
#
#                                              TargetRLF1  \
# 0     Atuhoama: Ahyehyɛde pii gye atuhoamafo akwaaba...
# 1     Ahintasɛm a wobu so betumi de ɔhaw kɛse aba mm...
# 2     Mmabun betumi de akwan horow adi dwuma de wɔn ...
# 3     Mmabun adwumayɛ ho nhyehyɛe ahorow: Ɔsatu ahor...
# 4     Ɛma wosusuw nsɛm ho ansa na woayi bi. Nsɛm a ɛ...
# ...                                                 ...
# 2613  Maambukizi ya zinaa (STIs), ikiwa ni pamoja na...
# 2614  HAPANA. Mimea na dawa mbadala haziwezi kuponya...
# 2615  Ikiwa unashuku kuwa mpenzi wako anaweza kuwa n...
# 2616  Kukomesha virusi vya ukimwi/UKIMWI (Virusi vya...
# 2617  Muda wa maisha wa mtu anayeishi na Ukimwi unaw...
#
#                                              TargetR1F1  \
# 0     Atuhoama: Ahyehyɛde pii gye atuhoamafo akwaaba...
# 1     Ahintasɛm a wobu so betumi de ɔhaw kɛse aba mm...
# 2     Mmabun betumi de akwan horow adi dwuma de wɔn ...
# 3     Mmabun adwumayɛ ho nhyehyɛe ahorow: Ɔsatu ahor...
# 4     Ɛma wosusuw nsɛm ho ansa na woayi bi. Nsɛm a ɛ...
# ...                                                 ...
# 2613  Maambukizi ya zinaa (STIs), ikiwa ni pamoja na...
# 2614  HAPANA. Mimea na dawa mbadala haziwezi kuponya...
# 2615  Ikiwa unashuku kuwa mpenzi wako anaweza kuwa n...
# 2616  Kukomesha virusi vya ukimwi/UKIMWI (Virusi vya...
# 2617  Muda wa maisha wa mtu anayeishi na Ukimwi unaw...
#
#                                               TargetLLM
# 0     Atuhoama: Ahyehyɛde pii gye atuhoamafo akwaaba...
# 1     Ahintasɛm a wobu so betumi de ɔhaw kɛse aba mm...
# 2     Mmabun betumi de akwan horow adi dwuma de wɔn ...
# 3     Mmabun adwumayɛ ho nhyehyɛe ahorow: Ɔsatu ahor...
# 4     Ɛma wosusuw nsɛm ho ansa na woayi bi. Nsɛm a ɛ...
# ...                                                 ...
# 2613  Maambukizi ya zinaa (STIs), ikiwa ni pamoja na...
# 2614  HAPANA. Mimea na dawa mbadala haziwezi kuponya...
# 2615  Ikiwa unashuku kuwa mpenzi wako anaweza kuwa n...
# 2616  Kukomesha virusi vya ukimwi/UKIMWI (Virusi vya...
# 2617  Muda wa maisha wa mtu anayeishi na Ukimwi unaw...
#
# [2618 rows x 4 columns]
