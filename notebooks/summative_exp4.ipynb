# %% [markdown]
# # Multilingual Health Q&A — Starter Notebook
#
# **Challenge:** Multilingual Health Question Answering in Low-Resource African Languages
#
# This notebook provides two baselines for the challenge:
#
# | Baseline | Approach | Speed | Quality |
# |---|---|---|---|
# | **Baseline 1** | TF-IDF retrieval | Very fast | Low |
# | **Baseline 2** | Multilingual LLM (mT5 / NLLB) | Moderate | Higher |
#
# **Task:** Given a health question in one of five African languages (Amharic, Luganda, Akan, Swahili, or English), generate a fluent and accurate answer in the **same language**.
#
# **Evaluation metrics:**
# - `TargetRLF1` — ROUGE-L F1 score
# - `TargetR1F1` — ROUGE-1 F1 score
# - `TargetLLM`  — LLM-as-a-Judge score
#
# > **Note:** All three submission columns should contain the same generated answer for each row. The platform computes all three metrics from that single answer.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
# Install required packages
# !pip install -q scikit-learn pandas numpy rouge-score
# !pip install -q transformers sentencepiece accelerate torch

print('✅ Packages installed')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 91.6 MB/s eta 0:00:00:00:01:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# ✅ Packages installed

# %%
import re
import random
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

warnings.filterwarnings('ignore')

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

pd.set_option('display.max_colwidth', 120)
pd.set_option('display.max_columns', None)

print('✅ Imports complete')
# Out:
# ✅ Imports complete

# %% [markdown]
# ## 2 — Set File Paths

# %%
DATA_DIR = Path('/kaggle/input/datasets/davidakachinwanze/zindi-summative')

TRAIN_PATH      = DATA_DIR / 'Train.csv'
TEST_PATH       = DATA_DIR / 'Test.csv'
VAL_PATH        = DATA_DIR / 'Val.csv'
SAMPLE_SUB_PATH = DATA_DIR / 'SampleSubmission.csv'

# Output paths for each baseline
OUTPUT_TFIDF = Path('/kaggle/working/submission_tfidf_baseline.csv')
OUTPUT_LLM   = Path('/kaggle/working/submission_llm_baseline.csv')

for path in [TRAIN_PATH, TEST_PATH, VAL_PATH, SAMPLE_SUB_PATH]:
    status = '✅' if path.exists() else '❌'
    print(f'{status} {path}')
# Out:
# ✅ /kaggle/input/datasets/davidakachinwanze/zindi-summative/Train.csv
# ✅ /kaggle/input/datasets/davidakachinwanze/zindi-summative/Test.csv
# ✅ /kaggle/input/datasets/davidakachinwanze/zindi-summative/Val.csv
# ✅ /kaggle/input/datasets/davidakachinwanze/zindi-summative/SampleSubmission.csv

# %% [markdown]
# ## 3 — Load and Preview the Data

# %%
train             = pd.read_csv(TRAIN_PATH)
test              = pd.read_csv(TEST_PATH)
val               = pd.read_csv(VAL_PATH)
sample_submission = pd.read_csv(SAMPLE_SUB_PATH)

print(f'Train shape             : {train.shape}')
print(f'Test shape              : {test.shape}')
print(f'Val shape               : {val.shape}')
print(f'Sample submission shape : {sample_submission.shape}')
print()
print('Train columns:', train.columns.tolist())
print('Test columns :', test.columns.tolist())
print('Val columns  :', val.columns.tolist())

display(train.head(3))
display(test.head(3))
display(sample_submission.head(3))
# Out:
# Train shape             : (29815, 4)
# Test shape              : (2618, 3)
# Val shape               : (6686, 4)
# Sample submission shape : (2618, 4)
#
# Train columns: ['ID', 'input', 'output', 'subset']
# Test columns : ['ID', 'input', 'subset']
# Val columns  : ['ID', 'input', 'output', 'subset']
#                        ID  \
# 0  ID_TR_Aka_Gha_A3B1799D
# 1  ID_TR_Aka_Gha_1C80317F
# 2  ID_TR_Aka_Gha_06671AD1
#
#                                                                                                                      input  \
# 0  Ɔkwan bɛn so na mmabunbɛtumi aboa wɔn mfɛfoɔ a nsa anaa nnubɔne ama wɔayɛ wɔn ayayadeɛ? Yei bi ne sɛnea wɔbɛkyekye w...
# 1          Edinnsiananmu bɛn na nnipa a ɛsono wɔn bɔbeasu taa de di dwuma, na yɛbɛyɛ dɛn ahwɛ ahu sɛ yɛde redi dwuma yiye?
# 2   Ɔkwan bɛn so na ɔbarima ne ɔbea nna a wɔtwe wɔn ho fi ho anaa nna mu adwumadi a wɔtwentwɛn so no boa ma asiane so tew?
#
#                                                                                                                     output  \
# 0  Mmabun betumi aboa atipɛnfo a ebia nsa anaa nnubɔne ama wɔayɛ wɔn ayayadeɛ so denam: Nkate fam mmoa a wɔde bɛma na w...
# 1                         Wɔ Ghana mu no, amanmmra no gye binary gender nkutoo tom a she/he edinnsiananmu nkutoo na ɛka ho
# 2  Sɛ wɔtwe wɔn ho fi nna mu anaasɛ wɔtwentwɛn wɔn nan ase a, ɛboa ma asiane nso tew denam asiane a ɛwɔ STI ne HIV a ɛb...
#
#     subset
# 0  Aka_Gha
# 1  Aka_Gha
# 2  Aka_Gha
#                        ID  \
# 0  ID_TS_Aka_Gha_A3B1799D
# 1  ID_TS_Aka_Gha_1C80317F
# 2  ID_TS_Aka_Gha_06671AD1
#
#                                                                                                                      input  \
# 0         Fa nneɛma a wɔde bɛyɛ nkyerɛkyerɛ nneɛma, adwumayɛbea ahorow, ne akuo ahorow a wɔreyɛ adwuma de asiw GBV ano ma.
# 1  Dɛn ne nea ebetumi afi hokwan a mmabun wɔ sɛ wonya nipadua mu ahofadi wɔ nna ne awoɔ akwahosan ho nhyehyɛe mu a wobu...
# 2  Akwan bɛn na mmabun bɛtumi afa so ehunu nsusuanso a ɛtumi aba ɛfa nnipa a wɔbɛgyina ho kɛkɛ 'bystander' wɔ bere a as...
#
#     subset
# 0  Aka_Gha
# 1  Aka_Gha
# 2  Aka_Gha
#                        ID             TargetRLF1             TargetR1F1  \
# 0  ID_TS_Aka_Gha_A3B1799D  Wuna dey craze, eweeh  Wuna dey craze, eweeh
# 1  ID_TS_Aka_Gha_1C80317F  Wuna dey craze, eweeh  Wuna dey craze, eweeh
# 2  ID_TS_Aka_Gha_06671AD1  Wuna dey craze, eweeh  Wuna dey craze, eweeh
#
#                TargetLLM
# 0  Wuna dey craze, eweeh
# 1  Wuna dey craze, eweeh
# 2  Wuna dey craze, eweeh

# %%
# Explore language distribution in training data
print('Language distribution in training set:')
display(train['subset'].value_counts())
# Out:
# Language distribution in training set:
# subset
# Eng_Uga    7624
# Aka_Gha    4455
# Eng_Gha    4443
# Eng_Eth    3915
# Lug_Uga    3383
# Eng_Ken    2080
# Swa_Ken    2070
# Amh_Eth    1845
# Name: count, dtype: int64

# %%
ID_COL           = 'ID'
TEST_ID_COL      = 'ID'
QUESTION_COL     = 'input'
TEST_QUESTION_COL= 'input'
ANSWER_COL       = 'output'
LANG_COL         = 'subset'
TEST_LANG_COL    = 'subset'

print(f'  Train ID        : {ID_COL}')
print(f'  Test ID         : {TEST_ID_COL}')
print(f'  Train question  : {QUESTION_COL}')
print(f'  Test question   : {TEST_QUESTION_COL}')
print(f'  Train answer    : {ANSWER_COL}')
# ── Language code mapping ──────────────────────────────────────────────────────
# The `subset` column encodes language and country as "<LangCode>_<CountryCode>".
# Only the first part identifies the language; the second is the country.
# This dictionary maps the language prefix to a full language name used in prompts.
SUBSET_TO_LANGUAGE = {
    'Eng': 'English',
    'Aka': 'Akan',
    'Lug': 'Luganda',
    'Swa': 'Swahili',
    'Amh': 'Amharic',
}

def subset_to_language_name(subset_code: str) -> str:
    """
    Extract the full language name from a subset code such as 'Amh_Eth' or 'Aka_Gha'.
    Falls back to the raw code if the prefix is not recognised.
    """
    if not subset_code or not isinstance(subset_code, str):
        return 'English'
    lang_prefix = subset_code.split('_')[0]
    return SUBSET_TO_LANGUAGE.get(lang_prefix, subset_code)

print('Language mapping:')
for code, name in SUBSET_TO_LANGUAGE.items():
    print(f'  {code}_* → {name}')
# Out:
#   Train ID        : ID
#   Test ID         : ID
#   Train question  : input
#   Test question   : input
#   Train answer    : output
# Language mapping:
#   Eng_* → English
#   Aka_* → Akan
#   Lug_* → Luganda
#   Swa_* → Swahili
#   Amh_* → Amharic

# %% [markdown]
# ## 5 — Text Cleaning

# %%
def clean_text(x):
    """Strip whitespace and handle null values."""
    if pd.isna(x):
        return ''
    return str(x).strip()

train[QUESTION_COL]      = train[QUESTION_COL].map(clean_text)
train[ANSWER_COL]        = train[ANSWER_COL].map(clean_text)
test[TEST_QUESTION_COL]  = test[TEST_QUESTION_COL].map(clean_text)
val[QUESTION_COL]        = val[QUESTION_COL].map(clean_text)
val[ANSWER_COL]          = val[ANSWER_COL].map(clean_text)

# Remove rows with empty questions or answers
train = train[(train[QUESTION_COL] != '') & (train[ANSWER_COL] != '')].reset_index(drop=True)
test  = test[test[TEST_QUESTION_COL]  != ''].reset_index(drop=True)
val   = val[(val[QUESTION_COL] != '') & (val[ANSWER_COL] != '')].reset_index(drop=True)

print(f'Cleaned train shape : {train.shape}')
print(f'Cleaned test shape  : {test.shape}')
print(f'Cleaned val shape   : {val.shape}')
# Out:
# Cleaned train shape : (29814, 4)
# Cleaned test shape  : (2618, 3)
# Cleaned val shape   : (6686, 4)

# %% [markdown]
# ## 7 — Evaluation Utilities
#
# ROUGE-1 and ROUGE-L scoring using whitespace tokenisation — safe for non-English scripts.

# %%
try:
    from rouge_score import rouge_scorer

    class WhitespaceTokenizer:
        """Whitespace tokeniser — language-agnostic and safe for African scripts."""
        def tokenize(self, text):
            if text is None:
                return []
            return str(text).strip().split()

    def compute_rouge(predictions, references):
        """
        Compute mean ROUGE-1 and ROUGE-L F1 scores.

        Parameters
        ----------
        predictions : list[str]
        references  : list[str]

        Returns
        -------
        dict with rouge1_f1 and rougeL_f1
        """
        scorer = rouge_scorer.RougeScorer(
            ['rouge1', 'rougeL'],
            tokenizer    = WhitespaceTokenizer(),
            use_stemmer  = False,
        )
        r1_scores, rl_scores = [], []

        for pred, ref in zip(predictions, references):
            score = scorer.score(str(ref), str(pred))
            r1_scores.append(score['rouge1'].fmeasure)
            rl_scores.append(score['rougeL'].fmeasure)

        return {
            'rouge1_f1': float(np.mean(r1_scores)) if r1_scores else 0.0,
            'rougeL_f1': float(np.mean(rl_scores)) if rl_scores else 0.0,
        }

    def compute_rouge_by_language(predictions, references, languages):
        """Compute ROUGE scores broken down by language."""
        results = {}
        lang_arr = np.array(languages)

        for lang in np.unique(lang_arr):
            mask    = lang_arr == lang
            preds_l = [p for p, m in zip(predictions, mask) if m]
            refs_l  = [r for r, m in zip(references,  mask) if m]
            results[lang] = compute_rouge(preds_l, refs_l)

        return pd.DataFrame(results).T

    print('✅ ROUGE scorer loaded')

except ImportError:
    print('⚠️  rouge-score not installed. Run: pip install rouge-score')
    compute_rouge = None
# Out:
# ✅ ROUGE scorer loaded

# %% [markdown]
# ## 8 — Baseline 1: TF-IDF Retrieval
#
# For each test question, find the most similar training question using TF-IDF character n-grams and return its answer.
#
# **Why character n-grams?** Character-level features work across scripts (Latin, Amharic Ge'ez, etc.) without requiring language-specific tokenisation.

# %%
class TfidfRetrievalAnswerer:
    """
    TF-IDF nearest-neighbour retrieval baseline.

    Builds a per-language model if a group column is available,
    falling back to a global model for unseen groups.
    """

    def __init__(self, question_col, answer_col, group_col=None,
                 ngram_range=(3, 5), max_features=200_000):
        self.question_col = question_col
        self.answer_col   = answer_col
        self.group_col    = group_col
        self.ngram_range  = ngram_range
        self.max_features = max_features
        self.models       = {}
        self.global_model = None

    def _fit_single(self, df):
        """Fit a vectoriser and nearest-neighbour index on a subset."""
        vectorizer = TfidfVectorizer(
            analyzer     = 'char_wb',
            ngram_range  = self.ngram_range,
            min_df       = 1,
            max_features = self.max_features,
            lowercase    = False,   # preserve case for non-Latin scripts
        )
        questions = df[self.question_col].fillna('').astype(str).tolist()
        answers   = df[self.answer_col].fillna('').astype(str).tolist()

        X  = vectorizer.fit_transform(questions)
        nn = NearestNeighbors(n_neighbors=1, metric='cosine')
        nn.fit(X)

        return {
            'vectorizer': vectorizer,
            'nn'        : nn,
            'answers'   : np.array(answers,   dtype=object),
            'questions' : np.array(questions, dtype=object),
        }

    def fit(self, df):
        """Fit the global model and per-group models."""
        self.global_model = self._fit_single(df)
        if self.group_col and self.group_col in df.columns:
            for group, sub in df.groupby(self.group_col):
                if len(sub) >= 2:
                    self.models[group] = self._fit_single(sub)
        print(f'  Fitted global model + {len(self.models)} group model(s)')
        return self

    def _predict_one_from_model(self, question, model):
        Xq        = model['vectorizer'].transform([question])
        dist, idx = model['nn'].kneighbors(Xq, n_neighbors=1)
        i         = idx[0][0]
        sim       = 1 - float(dist[0][0])
        return model['answers'][i], sim, model['questions'][i]

    def predict_one(self, question, group=None):
        model = self.models.get(group, self.global_model) if group is not None else self.global_model
        return self._predict_one_from_model(question, model)

    def predict(self, df, question_col, group_col=None):
        outputs, similarities, matched = [], [], []
        for _, row in df.iterrows():
            question = clean_text(row[question_col])
            group    = row[group_col] if group_col and group_col in df.columns else None
            answer, sim, matched_q = self.predict_one(question, group)
            outputs.append(answer)
            similarities.append(sim)
            matched.append(matched_q)
        return outputs, similarities, matched

print('✅ TfidfRetrievalAnswerer defined')
# Out:
# ✅ TfidfRetrievalAnswerer defined

# %%
# Choose grouping strategy — prefer config (language+country), else language
GROUP_COL      =  LANG_COL
TEST_GROUP_COL =  TEST_LANG_COL

print(f'Group column      : {GROUP_COL}')
print(f'Test group column : {TEST_GROUP_COL}')
# Out:
# Group column      : subset
# Test group column : subset

# %%
# ── Validate TF-IDF baseline on the local validation set ──────────────────────
print('Training TF-IDF retrieval baseline on training partition...')

answerer_valid = TfidfRetrievalAnswerer(
    question_col = QUESTION_COL,
    answer_col   = ANSWER_COL,
    group_col    = GROUP_COL,
).fit(train)

valid_pred, valid_sim, valid_match = answerer_valid.predict(
    val,
    question_col = QUESTION_COL,
    group_col    = GROUP_COL,
)

if compute_rouge:
    metrics = compute_rouge(valid_pred, val[ANSWER_COL].tolist())
    print(f'\n📊 TF-IDF Baseline — Validation ROUGE Scores')
    print(f'   ROUGE-1 F1 : {metrics["rouge1_f1"]:.4f}')
    print(f'   ROUGE-L F1 : {metrics["rougeL_f1"]:.4f}')

    # Break down by language
    if LANG_COL and LANG_COL in val.columns:
        print('\n📊 ROUGE scores by language:')
        lang_metrics = compute_rouge_by_language(
            valid_pred,
            val[ANSWER_COL].tolist(),
            val[LANG_COL].tolist()
        )
        display(lang_metrics.round(4))

# Preview
preview = val[[ID_COL, QUESTION_COL, ANSWER_COL]].copy()
preview['baseline_answer']        = valid_pred
preview['retrieval_similarity']   = [f'{s:.3f}' for s in valid_sim]
preview['matched_train_question'] = valid_match
display(preview.head(5))
# Out:
# Training TF-IDF retrieval baseline on training partition...
#   Fitted global model + 8 group model(s)
#
# 📊 TF-IDF Baseline — Validation ROUGE Scores
#    ROUGE-1 F1 : 0.4207
#    ROUGE-L F1 : 0.3655
#
# 📊 ROUGE scores by language:
#          rouge1_f1  rougeL_f1
# Aka_Gha     0.2832     0.1674
# Amh_Eth     0.1455     0.1353
# Eng_Eth     0.5170     0.4994
# Eng_Gha     0.2582     0.1707
# Eng_Ken     0.5989     0.5606
# Eng_Uga     0.5163     0.4709
# Lug_Uga     0.5155     0.4935
# Swa_Ken     0.6031     0.5672
#                        ID  \
# 0  ID_VL_Aka_Gha_A3B1799D
# 1  ID_VL_Aka_Gha_1C80317F
# 2  ID_VL_Aka_Gha_06671AD1
# 3  ID_VL_Aka_Gha_BDD640FB
# 4  ID_VL_Aka_Gha_46685257
#
#                                                                                                                      input  \
# 0  Sɛn na nwomasua ne adwuma nteteeɛ boa akuo a eye mmabun a wɔ hia neaɛma sokoronko ne ohaw ahorow, atubrafo, anaa wɔn...
# 1                                                        Dɛn nti na ɛho hia sɛ mmabun te wɔn nna ne awo hokwan ahorow ase?
# 2  Mɛyɛ dɛn atumi abɔ asisifo ho amanneɛ wɔ ɔkwan a etu mpɔn na ahobammɔ wom so, na anammɔn bɛn na metumi atu de ahwɛ a...
# 3  Ɔkwan bɛn so na mmabun betumi de akwan ahorow a egyina nnipa hokwan ahorow so adi dwuma, de akamfo nna ho nkyerɛkyer...
# 4  Dwuma bɛn na abɛɛfo mfidie 'Technology' di de boa mmabun ma wonya ɔhwɛ a ɛfata, a telehealth ne online resources ka ho?
#
#                                                                                                                     output  \
# 0  Nhyehyɛeɛ aa ama ne mu so te sɛ senea aborɔfo ka no 'STEM' ne 'vocational training' se ɛbɛ adrɛse mmabun kuokuo ahoh...
# 1  Nna ne awo hokwan ahorow a wɔte ase no ma mmabun tumi: Si gyinae a ɛfata wɔ wɔn nipadua, nna, ne abusuabɔ ho. Kamfo ...
# 2  Ayayade ho nsɛm a wɔbɛbɔ ho amanneɛ yiye na ahobammɔ wom no hwehwɛ sɛ wɔyɛ nneɛma a edidi so yi: Wɔkyerɛw ayayade no...
# 3  Mmabun betumi de akwan a, egyina nnipa hokwan ahorow so adi dwuma de akamfo nna ho nkyerɛkyerɛ a edi mũ wɔ sukuu ne ...
# 4  Abɛɛfo mfidie te sɛ telehealth ma mmabun kwan ma wonya ɔhwɛ fi wɔn fie. Wei yi akwansidie te sɛ lore a wobɛfo ɛnam b...
#
#                                                                                                            baseline_answer  \
# 0  Nkɔmmɔdi: Aban, NGO, ne amanaman ntam nnwumakuo ntam nkitahodiɛ bɛtumi ama nkitahodiɛ, nneɛma a wɔboaboa ano, ne dwu...
# 1  Mmara kwan so hokwan ahorow kyerɛ hokwan ahorow ne ahobammɔ a mmara de ma ankorankoro. Wɔ nna ne awo akwahosan ho no...
# 2  Akwan ahorow: Siesie Wo Ho Di Kan: Kyerɛw wo nsɛmmisa ne wo dadwen to hɔ ansa na woakɔ. Di Nokware: Kasa fa wo nna, ...
# 3  Mmabun betumi akasa ama nna ho nkyerɛkyerɛ a edi mu wɔ wɔn sukuu ne mpɔtam hɔ denam: Akuo a sukuufo di anim a wɔde w...
# 4                 Websites (nimdeɛ pa). Apps (de hwehwɛ nneɛma). SMS (nkɔmmɔbɔ mfidie). Telemedicine (intanɛt so ayaresa).
#
#   retrieval_similarity  \
# 0                0.378
# 1                0.545
# 2                0.292
# 3                0.642
# 4                0.412
#
#                                                                                                     matched_train_question
# 0  Ɔkwan bɛn so na aban ahorow, ahyehyɛde ahorow a ɛnyɛ aban de (NGOs), ne amanaman ntam nnwumakuw ne fekubɔ betumi ahy...
# 1                  Dɛn ne mmara kwan so ahokwan ahorow, na dɛn nti na ɛho hia sɛ mmabun hu ho wɔ nna ne awoɔ akwahosan ho?
# 2  Akwan bɛn so na metumi ne dɔkotafo anaa nɛɛse akasa afa me awoɔ mu apɔmuden ho na mahwɛ sɛ wɔate m’ahiadeɛ ne me dad...
# 3                           Ɔkwan bɛn so na mmabun betumi akasa afa nna ho nkyerɛkyerɛ a edi mu wɔ wɔn sukuu ne mpɔtam hɔ?
# 4                                Sɛn na abɛɛfo mfidie 'technology' boa SRH nimdeɛ ho nkyerɛkyerɛ a ɛkɔ so wɔ wiase nyinaa?

# %%
# ── Train on all data and predict test answers ─────────────────────────────────
print('Training TF-IDF retrieval on full training set...')

answerer = TfidfRetrievalAnswerer(
    question_col = QUESTION_COL,
    answer_col   = ANSWER_COL,
    group_col    = GROUP_COL,
).fit(train)

test_pred_tfidf, test_sim, test_match = answerer.predict(
    test,
    question_col = TEST_QUESTION_COL,
    group_col    = TEST_GROUP_COL,
)

print(f'Generated {len(test_pred_tfidf)} predictions')

preview = test[[TEST_ID_COL, TEST_QUESTION_COL]].copy()
preview['baseline_answer']      = test_pred_tfidf
preview['retrieval_similarity'] = [f'{s:.3f}' for s in test_sim]
display(preview.head(5))
# Out:
# Training TF-IDF retrieval on full training set...
#   Fitted global model + 8 group model(s)
# Generated 2618 predictions
#                        ID  \
# 0  ID_TS_Aka_Gha_A3B1799D
# 1  ID_TS_Aka_Gha_1C80317F
# 2  ID_TS_Aka_Gha_06671AD1
# 3  ID_TS_Aka_Gha_BDD640FB
# 4  ID_TS_Aka_Gha_46685257
#
#                                                                                                                      input  \
# 0         Fa nneɛma a wɔde bɛyɛ nkyerɛkyerɛ nneɛma, adwumayɛbea ahorow, ne akuo ahorow a wɔreyɛ adwuma de asiw GBV ano ma.
# 1  Dɛn ne nea ebetumi afi hokwan a mmabun wɔ sɛ wonya nipadua mu ahofadi wɔ nna ne awoɔ akwahosan ho nhyehyɛe mu a wobu...
# 2  Akwan bɛn na mmabun bɛtumi afa so ehunu nsusuanso a ɛtumi aba ɛfa nnipa a wɔbɛgyina ho kɛkɛ 'bystander' wɔ bere a as...
# 3  Sɛnea amammerɛ mu mmra, asetena mu suban, ne tumi mu nsakraeɛ a ɛwɔ nkuro ne atuhoamafoɔ mu ka mmaabun nkitahodi ne ...
# 4                                      Adɛn nti na mmara nsesaeɛ 'policy advocacy' ho hia ma mmabun nyin wɔ biribiara mu ?
#
#                                                                                                            baseline_answer  \
# 0  Nhomasua Nneɛma: Hwehwɛ nhoma, nkratawa, anaa intanɛt so nneɛma a efi nnwumakuo ahorow a wogye wɔn di mu a ɛfa GBV n...
# 1  Yiw, mmabun betumi ahwehwɛ mmara kwan so mmoa sɛ wogye di sɛ wɔabu hokwan a wɔwɔ sɛ wodi wɔn ho so wɔ nipadua mu no ...
# 2  Nnipa a wɔn ho nka ho tee yɛ biribi. Ɛsi basabasayɛ kwan denam mmoa a wɔde ma (bystanders) ma wohu/yɛ biribi no so. ...
# 3  Hokwan a mmabun akannifoɔ de wɔn ho bɛhyɛ dwumadiɛ a ɛma wɔn tumi yɛ adwuma, afotuo nhyehyɛeɛ, ne atipɛnfoɔ adesua n...
# 4  Kae sɛ obiara suahunu yɛ soronko. Dwen sɛ obiara wɔ n'adwene kyerɛ. Gye tom sɛ amammerɛ ne nyamesom sesa nkurɔfoɔ su...
#
#   retrieval_similarity
# 0                0.464
# 1                0.451
# 2                0.250
# 3                0.357
# 4                0.361

# %% [markdown]
# ## 9 — Baseline 2: Multilingual LLM (mT5 / AfroLM)
#
# This baseline uses a pre-trained multilingual sequence-to-sequence model to generate answers directly, without retrieval.
#
# **Model options (choose one):**
#
# | Model | Languages | Size | Notes |
# |---|---|---|---|
# | `google/mt5-small` | 101 languages incl. Swahili | 300M | Fast, good multilingual coverage |
# | `google/mt5-base` | 101 languages | 580M | Better quality, slower |
# | `facebook/nllb-200-distilled-600M` | 200 languages incl. Luganda, Akan | 600M | Best African language coverage |
# | `Helsinki-NLP/opus-mt-mul-en` | Many → English | 300M | English output only |
#
# > **Recommendation:** Start with `google/mt5-small` for speed, then try `facebook/nllb-200-distilled-600M` for better coverage of low-resource languages.
#
# **For a strong fine-tuned solution:**
# Fine-tune `google/mt5-base` or `facebook/nllb-200-distilled-600M` on the provided training data using the Hugging Face `Seq2SeqTrainer`. See the fine-tuning section at the end of this notebook.

# %%
import torch
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# ── Configuration ──────────────────────────────────────────────────────────────
MODEL_NAME = 'google/mt5-small'
# MODEL_NAME = 'google/mt5-base'
# MODEL_NAME = 'facebook/nllb-200-distilled-600M'

MAX_INPUT_LENGTH  = 128
MAX_OUTPUT_LENGTH = 256
BATCH_SIZE_LLM    = 2
NUM_BEAMS         = 4

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Device  : {DEVICE}')
print(f'Model   : {MODEL_NAME}')

if DEVICE == 'cuda':
    print(f'GPU     : {torch.cuda.get_device_name(0)}')
    print(f'VRAM    : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
# Out:
# Device  : cuda
# Model   : google/mt5-small
# GPU     : Tesla T4
# VRAM    : 15.6 GB

# %%
# ── Load the model and tokeniser ───────────────────────────────────────────────
print(f'Loading {MODEL_NAME}...')
print('This may take a few minutes on first run (downloading model weights).')

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model_llm = AutoModelForSeq2SeqLM.from_pretrained(
    MODEL_NAME,
    # Always load in float32 so gradient computation stays in float32.
    # fp16/bf16 mixed precision is handled by the Trainer via grad scaler,
    # not by storing the model weights in float16 directly.
    torch_dtype = torch.float32,
)
model_llm = model_llm.to(DEVICE)
model_llm.eval()

print(f'✅ {MODEL_NAME} loaded on {DEVICE}')
print(f'   Parameters : {sum(p.numel() for p in model_llm.parameters()) / 1e6:.0f}M')
# Out:
# Loading google/mt5-small...
# This may take a few minutes on first run (downloading model weights).
# config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# pytorch_model.bin:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/192 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie shared.weight to decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# ✅ google/mt5-small loaded on cuda
#    Parameters : 556M

# %%
import re

def build_prompt(question: str, language: str = None) -> str:
    """
    Build an input prompt for the model.

    For mT5: prefix the question with a task description.
    The model learns to associate the prefix with the generation task.

    `language` may be a raw subset code (e.g. 'Amh_Eth') or a full language
    name. It is resolved through `subset_to_language_name` so the model always
    receives a human-readable language name in the prompt rather than an opaque
    code.

    Parameters
    ----------
    question : str
        The health question to answer.
    language : str, optional
        Subset code (e.g. 'Amh_Eth') or full language name. Resolved to a
        human-readable name before being inserted into the prompt.

    Returns
    -------
    str
    """
    # if language:
    #     lang_name = subset_to_language_name(language)
    #     return f'Answer this health question in {lang_name}: {question}'
    # return f'Answer this health question: {question}'
    return str(question).strip()


def generate_answers_batch(questions: list, languages: list = None,
                           batch_size: int = BATCH_SIZE_LLM) -> list:
    """
    Generate answers for a list of questions using the loaded LLM.

    Processes questions in batches to avoid out-of-memory errors.

    Parameters
    ----------
    questions : list[str]
    languages : list[str], optional
    batch_size : int

    Returns
    -------
    list[str]
    """
    if languages is None:
        languages = [None] * len(questions)

    all_answers = []
    n_batches   = (len(questions) + batch_size - 1) // batch_size

    for batch_idx in range(n_batches):
        start = batch_idx * batch_size
        end   = min(start + batch_size, len(questions))

        batch_questions = questions[start:end]
        batch_languages = languages[start:end]

        # Build prompts
        prompts = [
            build_prompt(q, l)
            for q, l in zip(batch_questions, batch_languages)
        ]

        # Tokenise
        inputs = tokenizer(
            prompts,
            return_tensors = 'pt',
            padding        = True,
            truncation     = True,
            max_length     = MAX_INPUT_LENGTH,
        ).to(DEVICE)

        # Generate
        with torch.no_grad():
            outputs = model_llm.generate(
                **inputs,
                max_new_tokens  = MAX_OUTPUT_LENGTH,
                num_beams       = NUM_BEAMS,
                early_stopping  = True,
                no_repeat_ngram_size = 3,
            )

        # Decode
        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        # Post-process: strip mT5 sentinel tokens (<extra_id_N>) that the
        # model may emit when it has not been fine-tuned on a seq2seq task.
        # mT5 is pre-trained with a span-corruption objective that uses these
        # tokens as placeholders; a zero-shot prompt may trigger them because
        # the model has never been trained to suppress them in open generation.
        cleaned = [re.sub(r'<extra_id_\d+>', '', ans).strip() for ans in decoded]
        all_answers.extend(cleaned)

        if (batch_idx + 1) % 10 == 0 or (batch_idx + 1) == n_batches:
            print(f'  Batch {batch_idx + 1}/{n_batches} — {end}/{len(questions)} questions processed')

    return all_answers

print('✅ LLM generation functions defined')
# Out:
# ✅ LLM generation functions defined

# %%
# ── Quick sanity check on a few examples ──────────────────────────────────────
print('Running sanity check on 3 validation examples...')

sample     = val.head(3)
q_sample   = sample[QUESTION_COL].tolist()
l_sample   = sample[LANG_COL].tolist() if LANG_COL else None
ref_sample = sample[ANSWER_COL].tolist()

gen_sample = generate_answers_batch(q_sample, l_sample, batch_size=3)

for i, (q, ref, gen) in enumerate(zip(q_sample, ref_sample, gen_sample)):
    lang = l_sample[i] if l_sample else 'unknown'
    print(f'\n[{i+1}] Language : {lang}')
    print(f'    Question  : {q[:120]}')
    print(f'    Reference : {ref[:120]}')
    print(f'    Generated : {gen[:120]}')
# Out:
# Running sanity check on 3 validation examples...
#   Batch 1/1 — 3/3 questions processed
#
# [1] Language : Aka_Gha
#     Question  : Sɛn na nwomasua ne adwuma nteteeɛ boa akuo a eye mmabun a wɔ hia neaɛma sokoronko ne ohaw ahorow, atubrafo, anaa wɔn a w
#     Reference : Nhyehyɛeɛ aa ama ne mu so te sɛ senea aborɔfo ka no 'STEM' ne 'vocational training' se ɛbɛ adrɛse mmabun kuokuo ahohia s
#     Generated : ?
#
# [2] Language : Aka_Gha
#     Question  : Dɛn nti na ɛho hia sɛ mmabun te wɔn nna ne awo hokwan ahorow ase?
#     Reference : Nna ne awo hokwan ahorow a wɔte ase no ma mmabun tumi: Si gyinae a ɛfata wɔ wɔn nipadua, nna, ne abusuabɔ ho. Kamfo wɔn
#     Generated : ?
#
# [3] Language : Aka_Gha
#     Question  : Mɛyɛ dɛn atumi abɔ asisifo ho amanneɛ wɔ ɔkwan a etu mpɔn na ahobammɔ wom so, na anammɔn bɛn na metumi atu de ahwɛ ahu s
#     Reference : Ayayade ho nsɛm a wɔbɛbɔ ho amanneɛ yiye na ahobammɔ wom no hwehwɛ sɛ wɔyɛ nneɛma a edidi so yi: Wɔkyerɛw ayayade no ho
#     Generated : ?

# %%
# ── Validate LLM baseline on the local validation set ─────────────────────────
# Note: this cell can take several minutes depending on your hardware.
# Reduce VALIDATION_SAMPLE_SIZE to speed it up during experimentation.

VALIDATION_SAMPLE_SIZE = 200   # Set to None to evaluate on the full validation set

if VALIDATION_SAMPLE_SIZE:
    val_sample = val.sample(
        n            = min(VALIDATION_SAMPLE_SIZE, len(val)),
        random_state = SEED
    )
else:
    val_sample = val

print(f'Evaluating LLM baseline on {len(val_sample)} validation examples...')

val_questions = val_sample[QUESTION_COL].tolist()
val_languages = val_sample[LANG_COL].tolist() if LANG_COL else None
val_references= val_sample[ANSWER_COL].tolist()

val_predictions_llm = generate_answers_batch(val_questions, val_languages)

if compute_rouge:
    metrics_llm = compute_rouge(val_predictions_llm, val_references)
    print(f'\n📊 LLM Baseline — Validation ROUGE Scores ({MODEL_NAME})')
    print(f'   ROUGE-1 F1 : {metrics_llm["rouge1_f1"]:.4f}')
    print(f'   ROUGE-L F1 : {metrics_llm["rougeL_f1"]:.4f}')

    if LANG_COL and LANG_COL in val_sample.columns:
        print('\n📊 ROUGE scores by language (LLM baseline):')
        lang_metrics_llm = compute_rouge_by_language(
            val_predictions_llm,
            val_references,
            val_sample[LANG_COL].tolist()
        )
        display(lang_metrics_llm.round(4))
# Out:
# Evaluating LLM baseline on 200 validation examples...
#   Batch 10/100 — 20/200 questions processed
#   Batch 20/100 — 40/200 questions processed
#   Batch 30/100 — 60/200 questions processed
#   Batch 40/100 — 80/200 questions processed
#   Batch 50/100 — 100/200 questions processed
#   Batch 60/100 — 120/200 questions processed
#   Batch 70/100 — 140/200 questions processed
#   Batch 80/100 — 160/200 questions processed
#   Batch 90/100 — 180/200 questions processed
#   Batch 100/100 — 200/200 questions processed
#
# 📊 LLM Baseline — Validation ROUGE Scores (google/mt5-small)
#    ROUGE-1 F1 : 0.0019
#    ROUGE-L F1 : 0.0019
#
# 📊 ROUGE scores by language (LLM baseline):
#          rouge1_f1  rougeL_f1
# Aka_Gha     0.0000     0.0000
# Amh_Eth     0.0151     0.0151
# Eng_Eth     0.0000     0.0000
# Eng_Gha     0.0018     0.0018
# Eng_Ken     0.0000     0.0000
# Eng_Uga     0.0000     0.0000
# Lug_Uga     0.0000     0.0000
# Swa_Ken     0.0000     0.0000

# %%
# ── Generate LLM predictions for the full test set ────────────────────────────
print(f'Generating LLM answers for {len(test)} test questions...')
print('This may take several minutes.')

test_questions_all = test[TEST_QUESTION_COL].tolist()
test_languages_all = test[TEST_LANG_COL].tolist() if TEST_LANG_COL else None

test_pred_llm = generate_answers_batch(test_questions_all, test_languages_all)

print(f'\n✅ Generated {len(test_pred_llm)} answers')

# Preview
preview_llm = test[[TEST_ID_COL, TEST_QUESTION_COL]].copy()
preview_llm['llm_answer'] = test_pred_llm
display(preview_llm.head(5))
# Out:
# Generating LLM answers for 2618 test questions...
# This may take several minutes.
#   Batch 10/1309 — 20/2618 questions processed
#   Batch 20/1309 — 40/2618 questions processed
#   Batch 30/1309 — 60/2618 questions processed
#   Batch 40/1309 — 80/2618 questions processed
#   Batch 50/1309 — 100/2618 questions processed
#   Batch 60/1309 — 120/2618 questions processed
#   Batch 70/1309 — 140/2618 questions processed
#   Batch 80/1309 — 160/2618 questions processed
#   Batch 90/1309 — 180/2618 questions processed
#   Batch 100/1309 — 200/2618 questions processed
#   Batch 110/1309 — 220/2618 questions processed
#   Batch 120/1309 — 240/2618 questions processed
#   Batch 130/1309 — 260/2618 questions processed
#   Batch 140/1309 — 280/2618 questions processed
#   Batch 150/1309 — 300/2618 questions processed
#   Batch 160/1309 — 320/2618 questions processed
#   Batch 170/1309 — 340/2618 questions processed
#   Batch 180/1309 — 360/2618 questions processed
#   Batch 190/1309 — 380/2618 questions processed
#   Batch 200/1309 — 400/2618 questions processed
#   Batch 210/1309 — 420/2618 questions processed
#   Batch 220/1309 — 440/2618 questions processed
#   Batch 230/1309 — 460/2618 questions processed
#   Batch 240/1309 — 480/2618 questions processed
#   Batch 250/1309 — 500/2618 questions processed
#   Batch 260/1309 — 520/2618 questions processed
#   Batch 270/1309 — 540/2618 questions processed
#   Batch 280/1309 — 560/2618 questions processed
#   Batch 290/1309 — 580/2618 questions processed
#   Batch 300/1309 — 600/2618 questions processed
#   Batch 310/1309 — 620/2618 questions processed
#   Batch 320/1309 — 640/2618 questions processed
#   Batch 330/1309 — 660/2618 questions processed
#   Batch 340/1309 — 680/2618 questions processed
#   Batch 350/1309 — 700/2618 questions processed
#   Batch 360/1309 — 720/2618 questions processed
#   Batch 370/1309 — 740/2618 questions processed
#   Batch 380/1309 — 760/2618 questions processed
#   Batch 390/1309 — 780/2618 questions processed
#   Batch 400/1309 — 800/2618 questions processed
#   Batch 410/1309 — 820/2618 questions processed
#   Batch 420/1309 — 840/2618 questions processed
#   Batch 430/1309 — 860/2618 questions processed
#   Batch 440/1309 — 880/2618 questions processed
#   Batch 450/1309 — 900/2618 questions processed
#   Batch 460/1309 — 920/2618 questions processed
#   Batch 470/1309 — 940/2618 questions processed
#   Batch 480/1309 — 960/2618 questions processed
#   Batch 490/1309 — 980/2618 questions processed
#   Batch 500/1309 — 1000/2618 questions processed
#   Batch 510/1309 — 1020/2618 questions processed
#   Batch 520/1309 — 1040/2618 questions processed
#   Batch 530/1309 — 1060/2618 questions processed
#   Batch 540/1309 — 1080/2618 questions processed
#   Batch 550/1309 — 1100/2618 questions processed
#   Batch 560/1309 — 1120/2618 questions processed
#   Batch 570/1309 — 1140/2618 questions processed
#   Batch 580/1309 — 1160/2618 questions processed
#   Batch 590/1309 — 1180/2618 questions processed
#   Batch 600/1309 — 1200/2618 questions processed
#   Batch 610/1309 — 1220/2618 questions processed
#   Batch 620/1309 — 1240/2618 questions processed
#   Batch 630/1309 — 1260/2618 questions processed
#   Batch 640/1309 — 1280/2618 questions processed
#   Batch 650/1309 — 1300/2618 questions processed
#   Batch 660/1309 — 1320/2618 questions processed
#   Batch 670/1309 — 1340/2618 questions processed
#   Batch 680/1309 — 1360/2618 questions processed
#   Batch 690/1309 — 1380/2618 questions processed
#   Batch 700/1309 — 1400/2618 questions processed
#   Batch 710/1309 — 1420/2618 questions processed
#   Batch 720/1309 — 1440/2618 questions processed
#   Batch 730/1309 — 1460/2618 questions processed
#   Batch 740/1309 — 1480/2618 questions processed
#   Batch 750/1309 — 1500/2618 questions processed
#   Batch 760/1309 — 1520/2618 questions processed
#   Batch 770/1309 — 1540/2618 questions processed
#   Batch 780/1309 — 1560/2618 questions processed
#   Batch 790/1309 — 1580/2618 questions processed
#   Batch 800/1309 — 1600/2618 questions processed
#   Batch 810/1309 — 1620/2618 questions processed
#   Batch 820/1309 — 1640/2618 questions processed
#   Batch 830/1309 — 1660/2618 questions processed
#   Batch 840/1309 — 1680/2618 questions processed
#   Batch 850/1309 — 1700/2618 questions processed
#   Batch 860/1309 — 1720/2618 questions processed
#   Batch 870/1309 — 1740/2618 questions processed
#   Batch 880/1309 — 1760/2618 questions processed
#   Batch 890/1309 — 1780/2618 questions processed
#   Batch 900/1309 — 1800/2618 questions processed
#   Batch 910/1309 — 1820/2618 questions processed
#   Batch 920/1309 — 1840/2618 questions processed
#   Batch 930/1309 — 1860/2618 questions processed
#   Batch 940/1309 — 1880/2618 questions processed
#   Batch 950/1309 — 1900/2618 questions processed
#   Batch 960/1309 — 1920/2618 questions processed
#   Batch 970/1309 — 1940/2618 questions processed
#   Batch 980/1309 — 1960/2618 questions processed
#   Batch 990/1309 — 1980/2618 questions processed
#   Batch 1000/1309 — 2000/2618 questions processed
#   Batch 1010/1309 — 2020/2618 questions processed
#   Batch 1020/1309 — 2040/2618 questions processed
#   Batch 1030/1309 — 2060/2618 questions processed
#   Batch 1040/1309 — 2080/2618 questions processed
#   Batch 1050/1309 — 2100/2618 questions processed
#   Batch 1060/1309 — 2120/2618 questions processed
#   Batch 1070/1309 — 2140/2618 questions processed
#   Batch 1080/1309 — 2160/2618 questions processed
#   Batch 1090/1309 — 2180/2618 questions processed
#   Batch 1100/1309 — 2200/2618 questions processed
#   Batch 1110/1309 — 2220/2618 questions processed
#   Batch 1120/1309 — 2240/2618 questions processed
#   Batch 1130/1309 — 2260/2618 questions processed
#   Batch 1140/1309 — 2280/2618 questions processed
#   Batch 1150/1309 — 2300/2618 questions processed
#   Batch 1160/1309 — 2320/2618 questions processed
#   Batch 1170/1309 — 2340/2618 questions processed
#   Batch 1180/1309 — 2360/2618 questions processed
#   Batch 1190/1309 — 2380/2618 questions processed
#   Batch 1200/1309 — 2400/2618 questions processed
#   Batch 1210/1309 — 2420/2618 questions processed
#   Batch 1220/1309 — 2440/2618 questions processed
#   Batch 1230/1309 — 2460/2618 questions processed
#   Batch 1240/1309 — 2480/2618 questions processed
#   Batch 1250/1309 — 2500/2618 questions processed
#   Batch 1260/1309 — 2520/2618 questions processed
#   Batch 1270/1309 — 2540/2618 questions processed
#   Batch 1280/1309 — 2560/2618 questions processed
#   Batch 1290/1309 — 2580/2618 questions processed
#   Batch 1300/1309 — 2600/2618 questions processed
#   Batch 1309/1309 — 2618/2618 questions processed
#
# ✅ Generated 2618 answers
#                        ID  \
# 0  ID_TS_Aka_Gha_A3B1799D
# 1  ID_TS_Aka_Gha_1C80317F
# 2  ID_TS_Aka_Gha_06671AD1
# 3  ID_TS_Aka_Gha_BDD640FB
# 4  ID_TS_Aka_Gha_46685257
#
#                                                                                                                      input  \
# 0         Fa nneɛma a wɔde bɛyɛ nkyerɛkyerɛ nneɛma, adwumayɛbea ahorow, ne akuo ahorow a wɔreyɛ adwuma de asiw GBV ano ma.
# 1  Dɛn ne nea ebetumi afi hokwan a mmabun wɔ sɛ wonya nipadua mu ahofadi wɔ nna ne awoɔ akwahosan ho nhyehyɛe mu a wobu...
# 2  Akwan bɛn na mmabun bɛtumi afa so ehunu nsusuanso a ɛtumi aba ɛfa nnipa a wɔbɛgyina ho kɛkɛ 'bystander' wɔ bere a as...
# 3  Sɛnea amammerɛ mu mmra, asetena mu suban, ne tumi mu nsakraeɛ a ɛwɔ nkuro ne atuhoamafoɔ mu ka mmaabun nkitahodi ne ...
# 4                                      Adɛn nti na mmara nsesaeɛ 'policy advocacy' ho hia ma mmabun nyin wɔ biribiara mu ?
#
#    llm_answer
# 0  GBV ano ma
# 1     mu aba?
# 2           .
# 3           ?
# 4          mu

# %% [markdown]
# ## 10 — Create Submission Files
#
# Each submission must contain exactly four columns: `ID`, `TargetRLF1`, `TargetR1F1`, `TargetLLM`.
# All three target columns should contain the same generated answer.

# %%
def make_submission(ids, predictions, output_path):
    """
    Build and save a valid Zindi submission file.

    Parameters
    ----------
    ids         : array-like of row IDs
    predictions : list[str] of generated answers
    output_path : str or Path
    """
    # Belt-and-suspenders: strip any residual sentinel tokens before saving.
    clean_preds = [re.sub(r'<extra_id_\d+>', '', str(p)).strip() for p in predictions]

    sub = pd.DataFrame()
    sub['ID']         = ids
    sub['TargetRLF1'] = clean_preds
    sub['TargetR1F1'] = clean_preds
    sub['TargetLLM']  = clean_preds

    sub = sub[['ID', 'TargetRLF1', 'TargetR1F1', 'TargetLLM']]

    # ── Submission checks ─────────────────────────────────────────────────
    required_cols = ['ID', 'TargetRLF1', 'TargetR1F1', 'TargetLLM']
    assert list(sub.columns) == required_cols, \
        f'Expected columns {required_cols}, got {list(sub.columns)}'
    assert len(sub) == len(test), \
        f'Row count mismatch: {len(sub)} predictions vs {len(test)} test rows'
    assert sub[['TargetRLF1', 'TargetR1F1', 'TargetLLM']].notna().all().all(), \
        'Missing values found in submission'
    assert (sub['TargetRLF1'] == sub['TargetR1F1']).all(), \
        'TargetRLF1 and TargetR1F1 differ'
    assert (sub['TargetRLF1'] == sub['TargetLLM']).all(), \
        'TargetRLF1 and TargetLLM differ'

    sub.to_csv(output_path, index=False, encoding='utf-8')
    print(f'✅ Submission saved to: {output_path}')
    print(f'   Shape : {sub.shape}')
    display(sub.head(3))
    return sub


# ── Save TF-IDF submission ─────────────────────────────────────────────────────
print('Saving TF-IDF baseline submission...')
sub_tfidf = make_submission(test[TEST_ID_COL].values, test_pred_tfidf, OUTPUT_TFIDF)

print()

# ── Save LLM submission ────────────────────────────────────────────────────────
print('Saving LLM baseline submission...')
sub_llm = make_submission(test[TEST_ID_COL].values, test_pred_llm, OUTPUT_LLM)
# Out:
# Saving TF-IDF baseline submission...
# ✅ Submission saved to: /kaggle/working/submission_tfidf_baseline.csv
#    Shape : (2618, 4)
#                        ID  \
# 0  ID_TS_Aka_Gha_A3B1799D
# 1  ID_TS_Aka_Gha_1C80317F
# 2  ID_TS_Aka_Gha_06671AD1
#
#                                                                                                                 TargetRLF1  \
# 0  Nhomasua Nneɛma: Hwehwɛ nhoma, nkratawa, anaa intanɛt so nneɛma a efi nnwumakuo ahorow a wogye wɔn di mu a ɛfa GBV n...
# 1  Yiw, mmabun betumi ahwehwɛ mmara kwan so mmoa sɛ wogye di sɛ wɔabu hokwan a wɔwɔ sɛ wodi wɔn ho so wɔ nipadua mu no ...
# 2  Nnipa a wɔn ho nka ho tee yɛ biribi. Ɛsi basabasayɛ kwan denam mmoa a wɔde ma (bystanders) ma wohu/yɛ biribi no so. ...
#
#                                                                                                                 TargetR1F1  \
# 0  Nhomasua Nneɛma: Hwehwɛ nhoma, nkratawa, anaa intanɛt so nneɛma a efi nnwumakuo ahorow a wogye wɔn di mu a ɛfa GBV n...
# 1  Yiw, mmabun betumi ahwehwɛ mmara kwan so mmoa sɛ wogye di sɛ wɔabu hokwan a wɔwɔ sɛ wodi wɔn ho so wɔ nipadua mu no ...
# 2  Nnipa a wɔn ho nka ho tee yɛ biribi. Ɛsi basabasayɛ kwan denam mmoa a wɔde ma (bystanders) ma wohu/yɛ biribi no so. ...
#
#                                                                                                                  TargetLLM
# 0  Nhomasua Nneɛma: Hwehwɛ nhoma, nkratawa, anaa intanɛt so nneɛma a efi nnwumakuo ahorow a wogye wɔn di mu a ɛfa GBV n...
# 1  Yiw, mmabun betumi ahwehwɛ mmara kwan so mmoa sɛ wogye di sɛ wɔabu hokwan a wɔwɔ sɛ wodi wɔn ho so wɔ nipadua mu no ...
# 2  Nnipa a wɔn ho nka ho tee yɛ biribi. Ɛsi basabasayɛ kwan denam mmoa a wɔde ma (bystanders) ma wohu/yɛ biribi no so. ...
# Saving LLM baseline submission...
# ✅ Submission saved to: /kaggle/working/submission_llm_baseline.csv
#    Shape : (2618, 4)
#                        ID  TargetRLF1  TargetR1F1   TargetLLM
# 0  ID_TS_Aka_Gha_A3B1799D  GBV ano ma  GBV ano ma  GBV ano ma
# 1  ID_TS_Aka_Gha_1C80317F     mu aba?     mu aba?     mu aba?
# 2  ID_TS_Aka_Gha_06671AD1           .           .           .

# %% [markdown]
# ## 11 — Compare Baselines

# %%
if compute_rouge:
    # Recompute TF-IDF validation scores for comparison
    tfidf_preds_val, _, _ = answerer_valid.predict(
        val_sample, question_col=QUESTION_COL, group_col=GROUP_COL
    )
    metrics_tfidf = compute_rouge(tfidf_preds_val, val_references)

    comparison = pd.DataFrame({
        'Baseline'  : ['TF-IDF Retrieval', f'LLM ({MODEL_NAME})'],
        'ROUGE-1 F1': [metrics_tfidf['rouge1_f1'], metrics_llm['rouge1_f1']],
        'ROUGE-L F1': [metrics_tfidf['rougeL_f1'], metrics_llm['rougeL_f1']],
    })

    print('📊 Baseline Comparison (validation set):')
    display(comparison.round(4))
    print()
    print('Note: The LLM score shown here is for a zero-shot (untrained) model.')
    print('Fine-tuning on the training data will significantly improve this.')
# Out:
# 📊 Baseline Comparison (validation set):
#                  Baseline  ROUGE-1 F1  ROUGE-L F1
# 0        TF-IDF Retrieval      0.4135      0.3581
# 1  LLM (google/mt5-small)      0.0019      0.0019
# Note: The LLM score shown here is for a zero-shot (untrained) model.
# Fine-tuning on the training data will significantly improve this.

# %% [markdown]
# ## 12 — Fine-tuning the LLM on Training Data
#
# Fine-tuning adapts the pre-trained mT5 weights to the health QA task and all five languages. After training, answers are regenerated for the test set and a new submission file is saved.
#
# **Key fixes vs. the original template:**
# - Prompts are built with `build_prompt()` at training time — matching exactly what is used at inference
# - Language names (resolved from `subset`) are included in training prompts
# - Padding tokens in labels are masked to `-100` so the loss ignores them
# - `DataCollatorForSeq2Seq` handles dynamic padding correctly
# - A validation split monitors overfitting during training
# - After `trainer.train()`, the test set is regenerated and a new submission is saved

# %%
from transformers import (
    Seq2SeqTrainer,
    Seq2SeqTrainingArguments,
    DataCollatorForSeq2Seq,
)
from datasets import Dataset

# ── Fine-tuning configuration ──────────────────────────────────────────────
FINETUNE_OUTPUT_DIR     = './mt5-small-exp4-epochs5'
FINETUNE_EPOCHS         = 5
FINETUNE_BATCH_SIZE     = 2
FINETUNE_LEARNING_RATE  = 1e-4
FINETUNE_MAX_INPUT_LEN  = 128
FINETUNE_MAX_TARGET_LEN = 256
FINETUNE_VAL_SIZE       = 0.05
GRADIENT_ACCUM_STEPS    = 8

OUTPUT_FINETUNED = Path('/kaggle/working/submission_exp4_mt5small_epochs5.csv')

print(f'Fine-tuning config:')
print(f'  Model            : {MODEL_NAME}')
print(f'  Epochs           : {FINETUNE_EPOCHS}')
print(f'  Batch size       : {FINETUNE_BATCH_SIZE}')
print(f'  Learning rate    : {FINETUNE_LEARNING_RATE}')
print(f'  Max input tokens : {FINETUNE_MAX_INPUT_LEN}')
print(f'  Max target tokens: {FINETUNE_MAX_TARGET_LEN}')
print(f'  Val split        : {FINETUNE_VAL_SIZE:.0%}')
print(f'  Output dir       : {FINETUNE_OUTPUT_DIR}')
# Out:
# Fine-tuning config:
#   Model            : google/mt5-small
#   Epochs           : 5
#   Batch size       : 2
#   Learning rate    : 0.0001
#   Max input tokens : 128
#   Max target tokens: 256
#   Val split        : 5%
#   Output dir       : ./mt5-small-exp4-epochs5

# %%
# ── Build prompt-aware training dataset ───────────────────────────────────
# Critical: we use build_prompt() here so training inputs match inference
# inputs exactly. The language name (resolved from subset) is included so
# the model learns to condition its output on the target language.

def make_hf_dataset(df, question_col, answer_col, lang_col):
    """
    Convert a pandas DataFrame to a HuggingFace Dataset with prompt-formatted
    inputs and tokenised labels.

    Parameters
    ----------
    df           : pd.DataFrame
    question_col : str  — column containing the question text
    answer_col   : str  — column containing the reference answer
    lang_col     : str  — column containing the subset code (e.g. 'Amh_Eth')

    Returns
    -------
    datasets.Dataset with columns: input_ids, attention_mask, labels
    """
    records = []
    for _, row in df.iterrows():
        prompt = build_prompt(
            question = str(row[question_col]),
            language = str(row[lang_col]) if lang_col and lang_col in df.columns else None,
        )
        records.append({'prompt': prompt, 'answer': str(row[answer_col])})

    raw_ds = Dataset.from_list(records)

    def preprocess(examples):
        # Tokenise inputs (prompts)
        model_inputs = tokenizer(
            examples['prompt'],
            max_length  = FINETUNE_MAX_INPUT_LEN,
            truncation  = True,
            padding     = False,   # DataCollatorForSeq2Seq handles padding dynamically
        )
        # Tokenise targets (reference answers)
        # Use text_target= (the modern API). The older context manager
        # was removed in transformers >= 4.28 and must not be used.
        labels = tokenizer(
            text_target = examples['answer'],
            max_length  = FINETUNE_MAX_TARGET_LEN,
            truncation  = True,
            padding     = False,
        )
        # Mask padding tokens in labels so the loss ignores them.
        # Without this the model wastes capacity learning to predict pad tokens.
        label_ids = labels['input_ids']
        model_inputs['labels'] = [
            [(tok if tok != tokenizer.pad_token_id else -100) for tok in seq]
            for seq in label_ids
        ]
        return model_inputs

    return raw_ds.map(preprocess, batched=True, remove_columns=['prompt', 'answer'])


# ── Split off a validation set from training data ──────────────────────────
from sklearn.model_selection import train_test_split

train_df, val_ft_df = train_test_split(
    train,
    test_size    = FINETUNE_VAL_SIZE,
    random_state = SEED,
    stratify     = train[LANG_COL] if LANG_COL in train.columns else None,
)

# Use 30% of training data for faster experimentation
train_df = train_df.sample(frac=0.3, random_state=42)
print(f'Using {len(train_df):,} training examples (30% subset)')

print(f'Fine-tuning split — train: {len(train_df):,}  val: {len(val_ft_df):,}')

hf_train_ds = make_hf_dataset(train_df,  QUESTION_COL, ANSWER_COL, LANG_COL)
hf_val_ds   = make_hf_dataset(val_ft_df, QUESTION_COL, ANSWER_COL, LANG_COL)

print(f'HF train dataset : {hf_train_ds}')
print(f'HF val dataset   : {hf_val_ds}')
# Out:
# Using 8,497 training examples (30% subset)
# Fine-tuning split — train: 8,497  val: 1,491
# Map:   0%|          | 0/8497 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1491 [00:00<?, ? examples/s]
# HF train dataset : Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 8497
# })
# HF val dataset   : Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 1491
# })

# %%
# ── Data collator — handles dynamic padding and label masking ─────────────
data_collator = DataCollatorForSeq2Seq(
    tokenizer  = tokenizer,
    model      = model_llm,
    label_pad_token_id = -100,
    pad_to_multiple_of = 8,
)

# ── Training arguments ─────────────────────────────────────────────────────
training_args = Seq2SeqTrainingArguments(
    output_dir                  = FINETUNE_OUTPUT_DIR,
    num_train_epochs            = FINETUNE_EPOCHS,
    per_device_train_batch_size = FINETUNE_BATCH_SIZE,
    per_device_eval_batch_size  = FINETUNE_BATCH_SIZE,
    gradient_accumulation_steps = 8,
    learning_rate               = FINETUNE_LEARNING_RATE,
    predict_with_generate       = True,
    bf16                        = (DEVICE == 'cuda' and torch.cuda.is_bf16_supported()),
    fp16                        = (DEVICE == 'cuda' and not torch.cuda.is_bf16_supported()),
    eval_strategy               = 'epoch',
    save_strategy               = 'epoch',
    load_best_model_at_end      = True,
    metric_for_best_model       = 'eval_loss',
    logging_steps               = 100,
    generation_max_length       = FINETUNE_MAX_TARGET_LEN,
    report_to                   = 'none',
)

# ── Trainer ────────────────────────────────────────────────────────────────
trainer = Seq2SeqTrainer(
    model           = model_llm,
    args            = training_args,
    train_dataset   = hf_train_ds,
    eval_dataset    = hf_val_ds,
    processing_class = tokenizer,
    data_collator   = data_collator,
)

print('Starting fine-tuning...')
print(f'  Training on {len(hf_train_ds):,} examples for {FINETUNE_EPOCHS} epoch(s)')
print(f'  Validating on {len(hf_val_ds):,} examples after each epoch')

trainer.train()

print('\n✅ Fine-tuning complete')
print(f'   Best checkpoint saved to: {FINETUNE_OUTPUT_DIR}')
# Out:
# Starting fine-tuning...
#   Training on 8,497 examples for 5 epoch(s)
#   Validating on 1,491 examples after each epoch
#     <div>
#
#       <progress value='2129' max='2660' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2129/2660 1:25:33 < 21:21, 0.41 it/s, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>32.086960</td>
#       <td>3.096432</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>29.043660</td>
#       <td>2.882315</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>27.687590</td>
#       <td>2.779573</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>26.582944</td>
#       <td>2.724322</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     976         with _open_zipfile_writer(f) as opened_zipfile:
# --> 977             _save(
#     978                 obj,
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol, _disable_byteorder_record)
#    1285             # Now that it is on the CPU we can directly copy it into the zip file
# -> 1286             zip_file.write_record(name, storage, num_bytes)
#    1287
#
# RuntimeError: basic_ios::clear: iostream error
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_108/2455440254.py in <cell line: 0>()
#      41 print(f'  Validating on {len(hf_val_ds):,} examples after each epoch')
#      42
# ---> 43 trainer.train()
#      44
#      45 print('\n✅ Fine-tuning complete')
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2172                 hf_hub_utils.enable_progress_bars()
#    2173         else:
# -> 2174             return inner_training_loop(
#    2175                 args=args,
#    2176                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2639
#    2640             self.control = self.callback_handler.on_epoch_end(args, self.state, self.control)
# -> 2641             self._maybe_log_save_evaluate(
#    2642                 tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time, learning_rate=learning_rate
#    2643             )
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time, learning_rate)
#    3025
#    3026         if self.control.should_save:
# -> 3027             self._save_checkpoint(model, trial)
#    3028             self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#    3029
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _save_checkpoint(self, model, trial)
#    3143         if not self.args.save_only_model:
#    3144             # Save optimizer and scheduler
# -> 3145             self._save_optimizer_and_scheduler(output_dir)
#    3146             self._save_scaler(output_dir)
#    3147             # Save RNG state
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _save_optimizer_and_scheduler(self, output_dir)
#    3270         elif self.args.should_save:
#    3271             # deepspeed.save_checkpoint above saves model/optim/sched
# -> 3272             torch.save(self.optimizer.state_dict(), os.path.join(output_dir, OPTIMIZER_NAME))
#    3273
#    3274         # Save SCHEDULER & SCALER
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     974
#     975     if _use_new_zipfile_serialization:
# --> 976         with _open_zipfile_writer(f) as opened_zipfile:
#     977             _save(
#     978                 obj,
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in __exit__(self, *args)
#     806
#     807     def __exit__(self, *args) -> None:
# --> 808         self.file_like.write_end_of_file()
#     809         if self.file_stream is not None:
#     810             self.file_stream.close()
#
# RuntimeError: [enforce fail at inline_container.cc:668] . unexpected pos 1687758784 vs 1687758672

# %%
# ── Regenerate test predictions with the fine-tuned model ─────────────────
# model_llm now holds the best fine-tuned checkpoint (load_best_model_at_end=True).
# We reuse generate_answers_batch() directly — it already uses model_llm
# and applies the same build_prompt() + sentinel-token cleanup.

print(f'Generating fine-tuned answers for {len(test):,} test questions...')
model_llm.eval()

test_questions_ft = test[TEST_QUESTION_COL].tolist()
test_languages_ft = test[TEST_LANG_COL].tolist() if TEST_LANG_COL else None

test_pred_finetuned = generate_answers_batch(test_questions_ft, test_languages_ft)

print(f'\n✅ Generated {len(test_pred_finetuned):,} answers')

# Preview
preview_ft = test[[TEST_ID_COL, TEST_QUESTION_COL]].copy()
preview_ft['finetuned_answer'] = test_pred_finetuned
display(preview_ft.head(5))

# ── Validate on val set before saving ─────────────────────────────────────
if compute_rouge:
    val_q_ft  = val[QUESTION_COL].tolist()
    val_l_ft  = val[LANG_COL].tolist() if LANG_COL else None
    val_ref_ft = val[ANSWER_COL].tolist()

    val_pred_ft = generate_answers_batch(val_q_ft, val_l_ft)
    metrics_ft  = compute_rouge(val_pred_ft, val_ref_ft)

    print(f'\n📊 Fine-tuned LLM — Validation ROUGE Scores')
    print(f'   ROUGE-1 F1 : {metrics_ft["rouge1_f1"]:.4f}')
    print(f'   ROUGE-L F1 : {metrics_ft["rougeL_f1"]:.4f}')

    if LANG_COL and LANG_COL in val.columns:
        print('\n📊 ROUGE scores by language (fine-tuned model):')
        lang_metrics_ft = compute_rouge_by_language(
            val_pred_ft, val_ref_ft, val[LANG_COL].tolist()
        )
        display(lang_metrics_ft.round(4))

# ── Save fine-tuned submission ─────────────────────────────────────────────
print('\nSaving fine-tuned submission...')
sub_finetuned = make_submission(
    ids         = test[TEST_ID_COL].values,
    predictions = test_pred_finetuned,
    output_path = OUTPUT_FINETUNED,
)
# Out:
# Generating fine-tuned answers for 2,618 test questions...
#   Batch 10/1309 — 20/2618 questions processed
#   Batch 20/1309 — 40/2618 questions processed
#   Batch 30/1309 — 60/2618 questions processed
#   Batch 40/1309 — 80/2618 questions processed
#   Batch 50/1309 — 100/2618 questions processed
#   Batch 60/1309 — 120/2618 questions processed
#   Batch 70/1309 — 140/2618 questions processed
#   Batch 80/1309 — 160/2618 questions processed
#   Batch 90/1309 — 180/2618 questions processed
#   Batch 100/1309 — 200/2618 questions processed
#   Batch 110/1309 — 220/2618 questions processed
#   Batch 120/1309 — 240/2618 questions processed
#   Batch 130/1309 — 260/2618 questions processed
#   Batch 140/1309 — 280/2618 questions processed
#   Batch 150/1309 — 300/2618 questions processed
#   Batch 160/1309 — 320/2618 questions processed
#   Batch 170/1309 — 340/2618 questions processed
#   Batch 180/1309 — 360/2618 questions processed
#   Batch 190/1309 — 380/2618 questions processed
#   Batch 200/1309 — 400/2618 questions processed
#   Batch 210/1309 — 420/2618 questions processed
#   Batch 220/1309 — 440/2618 questions processed
#   Batch 230/1309 — 460/2618 questions processed
#   Batch 240/1309 — 480/2618 questions processed
#   Batch 250/1309 — 500/2618 questions processed
#   Batch 260/1309 — 520/2618 questions processed
#   Batch 270/1309 — 540/2618 questions processed
#   Batch 280/1309 — 560/2618 questions processed
#   Batch 290/1309 — 580/2618 questions processed
#   Batch 300/1309 — 600/2618 questions processed
#   Batch 310/1309 — 620/2618 questions processed
#   Batch 320/1309 — 640/2618 questions processed
#   Batch 330/1309 — 660/2618 questions processed
#   Batch 340/1309 — 680/2618 questions processed
#   Batch 350/1309 — 700/2618 questions processed
#   Batch 360/1309 — 720/2618 questions processed
#   Batch 370/1309 — 740/2618 questions processed
#   Batch 380/1309 — 760/2618 questions processed
#   Batch 390/1309 — 780/2618 questions processed
#   Batch 400/1309 — 800/2618 questions processed
#   Batch 410/1309 — 820/2618 questions processed
#   Batch 420/1309 — 840/2618 questions processed
#   Batch 430/1309 — 860/2618 questions processed
#   Batch 440/1309 — 880/2618 questions processed
#   Batch 450/1309 — 900/2618 questions processed
#   Batch 460/1309 — 920/2618 questions processed
#   Batch 470/1309 — 940/2618 questions processed
#   Batch 480/1309 — 960/2618 questions processed
#   Batch 490/1309 — 980/2618 questions processed
#   Batch 500/1309 — 1000/2618 questions processed
#   Batch 510/1309 — 1020/2618 questions processed
#   Batch 520/1309 — 1040/2618 questions processed
#   Batch 530/1309 — 1060/2618 questions processed
#   Batch 540/1309 — 1080/2618 questions processed
#   Batch 550/1309 — 1100/2618 questions processed
#   Batch 560/1309 — 1120/2618 questions processed
#   Batch 570/1309 — 1140/2618 questions processed
#   Batch 580/1309 — 1160/2618 questions processed
#   Batch 590/1309 — 1180/2618 questions processed
#   Batch 600/1309 — 1200/2618 questions processed
#   Batch 610/1309 — 1220/2618 questions processed
#   Batch 620/1309 — 1240/2618 questions processed
#   Batch 630/1309 — 1260/2618 questions processed
#   Batch 640/1309 — 1280/2618 questions processed
#   Batch 650/1309 — 1300/2618 questions processed
#   Batch 660/1309 — 1320/2618 questions processed
#   Batch 670/1309 — 1340/2618 questions processed
#   Batch 680/1309 — 1360/2618 questions processed
#   Batch 690/1309 — 1380/2618 questions processed
#   Batch 700/1309 — 1400/2618 questions processed
#   Batch 710/1309 — 1420/2618 questions processed
#   Batch 720/1309 — 1440/2618 questions processed
#   Batch 730/1309 — 1460/2618 questions processed
#   Batch 740/1309 — 1480/2618 questions processed
#   Batch 750/1309 — 1500/2618 questions processed
#   Batch 760/1309 — 1520/2618 questions processed
#   Batch 770/1309 — 1540/2618 questions processed
#   Batch 780/1309 — 1560/2618 questions processed
#   Batch 790/1309 — 1580/2618 questions processed
#   Batch 800/1309 — 1600/2618 questions processed
#   Batch 810/1309 — 1620/2618 questions processed
#   Batch 820/1309 — 1640/2618 questions processed
#   Batch 830/1309 — 1660/2618 questions processed
#   Batch 840/1309 — 1680/2618 questions processed
#   Batch 850/1309 — 1700/2618 questions processed
#   Batch 860/1309 — 1720/2618 questions processed
#   Batch 870/1309 — 1740/2618 questions processed
#   Batch 880/1309 — 1760/2618 questions processed
#   Batch 890/1309 — 1780/2618 questions processed
#   Batch 900/1309 — 1800/2618 questions processed
#   Batch 910/1309 — 1820/2618 questions processed
#   Batch 920/1309 — 1840/2618 questions processed
#   Batch 930/1309 — 1860/2618 questions processed
#   Batch 940/1309 — 1880/2618 questions processed
#   Batch 950/1309 — 1900/2618 questions processed
#   Batch 960/1309 — 1920/2618 questions processed
#   Batch 970/1309 — 1940/2618 questions processed
#   Batch 980/1309 — 1960/2618 questions processed
#   Batch 990/1309 — 1980/2618 questions processed
#   Batch 1000/1309 — 2000/2618 questions processed
#   Batch 1010/1309 — 2020/2618 questions processed
#   Batch 1020/1309 — 2040/2618 questions processed
#   Batch 1030/1309 — 2060/2618 questions processed
#   Batch 1040/1309 — 2080/2618 questions processed
#   Batch 1050/1309 — 2100/2618 questions processed
#   Batch 1060/1309 — 2120/2618 questions processed
#   Batch 1070/1309 — 2140/2618 questions processed
#   Batch 1080/1309 — 2160/2618 questions processed
#   Batch 1090/1309 — 2180/2618 questions processed
#   Batch 1100/1309 — 2200/2618 questions processed
#   Batch 1110/1309 — 2220/2618 questions processed
#   Batch 1120/1309 — 2240/2618 questions processed
#   Batch 1130/1309 — 2260/2618 questions processed
#   Batch 1140/1309 — 2280/2618 questions processed
#   Batch 1150/1309 — 2300/2618 questions processed
#   Batch 1160/1309 — 2320/2618 questions processed
#   Batch 1170/1309 — 2340/2618 questions processed
#   Batch 1180/1309 — 2360/2618 questions processed
#   Batch 1190/1309 — 2380/2618 questions processed
#   Batch 1200/1309 — 2400/2618 questions processed
#   Batch 1210/1309 — 2420/2618 questions processed
#   Batch 1220/1309 — 2440/2618 questions processed
#   Batch 1230/1309 — 2460/2618 questions processed
#   Batch 1240/1309 — 2480/2618 questions processed
#   Batch 1250/1309 — 2500/2618 questions processed
#   Batch 1260/1309 — 2520/2618 questions processed
#   Batch 1270/1309 — 2540/2618 questions processed
#   Batch 1280/1309 — 2560/2618 questions processed
#   Batch 1290/1309 — 2580/2618 questions processed
#   Batch 1300/1309 — 2600/2618 questions processed
#   Batch 1309/1309 — 2618/2618 questions processed
#
# ✅ Generated 2,618 answers
#                        ID  \
# 0  ID_TS_Aka_Gha_A3B1799D
# 1  ID_TS_Aka_Gha_1C80317F
# 2  ID_TS_Aka_Gha_06671AD1
# 3  ID_TS_Aka_Gha_BDD640FB
# 4  ID_TS_Aka_Gha_46685257
#
#                                                                                                                      input  \
# 0         Fa nneɛma a wɔde bɛyɛ nkyerɛkyerɛ nneɛma, adwumayɛbea ahorow, ne akuo ahorow a wɔreyɛ adwuma de asiw GBV ano ma.
# 1  Dɛn ne nea ebetumi afi hokwan a mmabun wɔ sɛ wonya nipadua mu ahofadi wɔ nna ne awoɔ akwahosan ho nhyehyɛe mu a wobu...
# 2  Akwan bɛn na mmabun bɛtumi afa so ehunu nsusuanso a ɛtumi aba ɛfa nnipa a wɔbɛgyina ho kɛkɛ 'bystander' wɔ bere a as...
# 3  Sɛnea amammerɛ mu mmra, asetena mu suban, ne tumi mu nsakraeɛ a ɛwɔ nkuro ne atuhoamafoɔ mu ka mmaabun nkitahodi ne ...
# 4                                      Adɛn nti na mmara nsesaeɛ 'policy advocacy' ho hia ma mmabun nyin wɔ biribiara mu ?
#
#                                                                                                           finetuned_answer
# 0                           This is a ɛbɛyɛ nkyerɛkyerɛ nneɛma, adwumayɛbea ahorow, ne akuo ahorow a wɔde bɛhwehwɛ nnaɛma.
# 1                    This is a ɛfa hokwan a mmabun wɔ sɛ wonya nipadua mu ahofadi wɔ nna ne awoɔ akwahosan ho nhyehyɛe mu.
# 2                                        This is a ɛfa nnipa a wɔbɛgyina ho kɛkɛ 'bystander' wɔ bere a asɛm bi mu ayɛ den.
# 3  Ammerɛ mu mmra, asetena mu suban, ne tumi mu nsakraeɛ a ɛwɔ nkurɔ ne atuhoamafoɔ mu ka mmaabun nkitahodi ne akannifo...
# 4              This is a question about, Policy Advocacy. Nsesaeɛ 'policy advocacy' ho hia ma mmabun nyin wɔ biribiara mu.
#   Batch 10/3343 — 20/6686 questions processed
#   Batch 20/3343 — 40/6686 questions processed
#   Batch 30/3343 — 60/6686 questions processed
#   Batch 40/3343 — 80/6686 questions processed
#   Batch 50/3343 — 100/6686 questions processed
#   Batch 60/3343 — 120/6686 questions processed
#   Batch 70/3343 — 140/6686 questions processed
#   Batch 80/3343 — 160/6686 questions processed
#   Batch 90/3343 — 180/6686 questions processed
#   Batch 100/3343 — 200/6686 questions processed
#   Batch 110/3343 — 220/6686 questions processed
#   Batch 120/3343 — 240/6686 questions processed
#   Batch 130/3343 — 260/6686 questions processed
#   Batch 140/3343 — 280/6686 questions processed
#   Batch 150/3343 — 300/6686 questions processed
#   Batch 160/3343 — 320/6686 questions processed
#   Batch 170/3343 — 340/6686 questions processed
#   Batch 180/3343 — 360/6686 questions processed
#   Batch 190/3343 — 380/6686 questions processed
#   Batch 200/3343 — 400/6686 questions processed
#   Batch 210/3343 — 420/6686 questions processed
#   Batch 220/3343 — 440/6686 questions processed
#   Batch 230/3343 — 460/6686 questions processed
#   Batch 240/3343 — 480/6686 questions processed
#   Batch 250/3343 — 500/6686 questions processed
#   Batch 260/3343 — 520/6686 questions processed
#   Batch 270/3343 — 540/6686 questions processed
#   Batch 280/3343 — 560/6686 questions processed
#   Batch 290/3343 — 580/6686 questions processed
#   Batch 300/3343 — 600/6686 questions processed
#   Batch 310/3343 — 620/6686 questions processed
#   Batch 320/3343 — 640/6686 questions processed
#   Batch 330/3343 — 660/6686 questions processed
#   Batch 340/3343 — 680/6686 questions processed
#   Batch 350/3343 — 700/6686 questions processed
#   Batch 360/3343 — 720/6686 questions processed
#   Batch 370/3343 — 740/6686 questions processed
#   Batch 380/3343 — 760/6686 questions processed
#   Batch 390/3343 — 780/6686 questions processed
#   Batch 400/3343 — 800/6686 questions processed
#   Batch 410/3343 — 820/6686 questions processed
#   Batch 420/3343 — 840/6686 questions processed
#   Batch 430/3343 — 860/6686 questions processed
#   Batch 440/3343 — 880/6686 questions processed
#   Batch 450/3343 — 900/6686 questions processed
#   Batch 460/3343 — 920/6686 questions processed
#   Batch 470/3343 — 940/6686 questions processed
#   Batch 480/3343 — 960/6686 questions processed
#   Batch 490/3343 — 980/6686 questions processed
#   Batch 500/3343 — 1000/6686 questions processed
#   Batch 510/3343 — 1020/6686 questions processed
#   Batch 520/3343 — 1040/6686 questions processed
#   Batch 530/3343 — 1060/6686 questions processed
#   Batch 540/3343 — 1080/6686 questions processed
#   Batch 550/3343 — 1100/6686 questions processed
#   Batch 560/3343 — 1120/6686 questions processed
#   Batch 570/3343 — 1140/6686 questions processed
#   Batch 580/3343 — 1160/6686 questions processed
#   Batch 590/3343 — 1180/6686 questions processed
#   Batch 600/3343 — 1200/6686 questions processed
#   Batch 610/3343 — 1220/6686 questions processed
#   Batch 620/3343 — 1240/6686 questions processed
#   Batch 630/3343 — 1260/6686 questions processed
#   Batch 640/3343 — 1280/6686 questions processed
#   Batch 650/3343 — 1300/6686 questions processed
#   Batch 660/3343 — 1320/6686 questions processed
#   Batch 670/3343 — 1340/6686 questions processed
#   Batch 680/3343 — 1360/6686 questions processed
#   Batch 690/3343 — 1380/6686 questions processed
#   Batch 700/3343 — 1400/6686 questions processed
#   Batch 710/3343 — 1420/6686 questions processed
#   Batch 720/3343 — 1440/6686 questions processed
#   Batch 730/3343 — 1460/6686 questions processed
#   Batch 740/3343 — 1480/6686 questions processed
#   Batch 750/3343 — 1500/6686 questions processed
#   Batch 760/3343 — 1520/6686 questions processed
#   Batch 770/3343 — 1540/6686 questions processed
#   Batch 780/3343 — 1560/6686 questions processed
#   Batch 790/3343 — 1580/6686 questions processed
#   Batch 800/3343 — 1600/6686 questions processed
#   Batch 810/3343 — 1620/6686 questions processed
#   Batch 820/3343 — 1640/6686 questions processed
#   Batch 830/3343 — 1660/6686 questions processed
#   Batch 840/3343 — 1680/6686 questions processed
#   Batch 850/3343 — 1700/6686 questions processed
#   Batch 860/3343 — 1720/6686 questions processed
#   Batch 870/3343 — 1740/6686 questions processed
#   Batch 880/3343 — 1760/6686 questions processed
#   Batch 890/3343 — 1780/6686 questions processed
#   Batch 900/3343 — 1800/6686 questions processed
#   Batch 910/3343 — 1820/6686 questions processed
#   Batch 920/3343 — 1840/6686 questions processed
#   Batch 930/3343 — 1860/6686 questions processed
#   Batch 940/3343 — 1880/6686 questions processed
#   Batch 950/3343 — 1900/6686 questions processed
#   Batch 960/3343 — 1920/6686 questions processed
#   Batch 970/3343 — 1940/6686 questions processed
#   Batch 980/3343 — 1960/6686 questions processed
#   Batch 990/3343 — 1980/6686 questions processed
#   Batch 1000/3343 — 2000/6686 questions processed
#   Batch 1010/3343 — 2020/6686 questions processed
#   Batch 1020/3343 — 2040/6686 questions processed
#   Batch 1030/3343 — 2060/6686 questions processed
#   Batch 1040/3343 — 2080/6686 questions processed
#   Batch 1050/3343 — 2100/6686 questions processed
#   Batch 1060/3343 — 2120/6686 questions processed
#   Batch 1070/3343 — 2140/6686 questions processed
#   Batch 1080/3343 — 2160/6686 questions processed
#   Batch 1090/3343 — 2180/6686 questions processed
#   Batch 1100/3343 — 2200/6686 questions processed
#   Batch 1110/3343 — 2220/6686 questions processed
#   Batch 1120/3343 — 2240/6686 questions processed
#   Batch 1130/3343 — 2260/6686 questions processed
#   Batch 1140/3343 — 2280/6686 questions processed
#   Batch 1150/3343 — 2300/6686 questions processed
#   Batch 1160/3343 — 2320/6686 questions processed
#   Batch 1170/3343 — 2340/6686 questions processed
#   Batch 1180/3343 — 2360/6686 questions processed
#   Batch 1190/3343 — 2380/6686 questions processed
#   Batch 1200/3343 — 2400/6686 questions processed
#   Batch 1210/3343 — 2420/6686 questions processed
#   Batch 1220/3343 — 2440/6686 questions processed
#   Batch 1230/3343 — 2460/6686 questions processed
#   Batch 1240/3343 — 2480/6686 questions processed
#   Batch 1250/3343 — 2500/6686 questions processed
#   Batch 1260/3343 — 2520/6686 questions processed
#   Batch 1270/3343 — 2540/6686 questions processed
#   Batch 1280/3343 — 2560/6686 questions processed
#   Batch 1290/3343 — 2580/6686 questions processed
#   Batch 1300/3343 — 2600/6686 questions processed
#   Batch 1310/3343 — 2620/6686 questions processed
#   Batch 1320/3343 — 2640/6686 questions processed
#   Batch 1330/3343 — 2660/6686 questions processed
#   Batch 1340/3343 — 2680/6686 questions processed
#   Batch 1350/3343 — 2700/6686 questions processed
#   Batch 1360/3343 — 2720/6686 questions processed
#   Batch 1370/3343 — 2740/6686 questions processed
#   Batch 1380/3343 — 2760/6686 questions processed
#   Batch 1390/3343 — 2780/6686 questions processed
#   Batch 1400/3343 — 2800/6686 questions processed
#   Batch 1410/3343 — 2820/6686 questions processed
#   Batch 1420/3343 — 2840/6686 questions processed
#   Batch 1430/3343 — 2860/6686 questions processed
#   Batch 1440/3343 — 2880/6686 questions processed
#   Batch 1450/3343 — 2900/6686 questions processed
#   Batch 1460/3343 — 2920/6686 questions processed
#   Batch 1470/3343 — 2940/6686 questions processed
#   Batch 1480/3343 — 2960/6686 questions processed
#   Batch 1490/3343 — 2980/6686 questions processed
#   Batch 1500/3343 — 3000/6686 questions processed
#   Batch 1510/3343 — 3020/6686 questions processed
#   Batch 1520/3343 — 3040/6686 questions processed
#   Batch 1530/3343 — 3060/6686 questions processed
#   Batch 1540/3343 — 3080/6686 questions processed
#   Batch 1550/3343 — 3100/6686 questions processed
#   Batch 1560/3343 — 3120/6686 questions processed
#   Batch 1570/3343 — 3140/6686 questions processed
#   Batch 1580/3343 — 3160/6686 questions processed
#   Batch 1590/3343 — 3180/6686 questions processed
#   Batch 1600/3343 — 3200/6686 questions processed
#   Batch 1610/3343 — 3220/6686 questions processed
#   Batch 1620/3343 — 3240/6686 questions processed
#   Batch 1630/3343 — 3260/6686 questions processed
#   Batch 1640/3343 — 3280/6686 questions processed
#   Batch 1650/3343 — 3300/6686 questions processed
#   Batch 1660/3343 — 3320/6686 questions processed
#   Batch 1670/3343 — 3340/6686 questions processed
#   Batch 1680/3343 — 3360/6686 questions processed
#   Batch 1690/3343 — 3380/6686 questions processed
#   Batch 1700/3343 — 3400/6686 questions processed
#   Batch 1710/3343 — 3420/6686 questions processed
#   Batch 1720/3343 — 3440/6686 questions processed
#   Batch 1730/3343 — 3460/6686 questions processed
#   Batch 1740/3343 — 3480/6686 questions processed
#   Batch 1750/3343 — 3500/6686 questions processed
#   Batch 1760/3343 — 3520/6686 questions processed
#   Batch 1770/3343 — 3540/6686 questions processed
#   Batch 1780/3343 — 3560/6686 questions processed
#   Batch 1790/3343 — 3580/6686 questions processed
#   Batch 1800/3343 — 3600/6686 questions processed
#   Batch 1810/3343 — 3620/6686 questions processed
#   Batch 1820/3343 — 3640/6686 questions processed
#   Batch 1830/3343 — 3660/6686 questions processed
#   Batch 1840/3343 — 3680/6686 questions processed
#   Batch 1850/3343 — 3700/6686 questions processed
#   Batch 1860/3343 — 3720/6686 questions processed
#   Batch 1870/3343 — 3740/6686 questions processed
#   Batch 1880/3343 — 3760/6686 questions processed
#   Batch 1890/3343 — 3780/6686 questions processed
#   Batch 1900/3343 — 3800/6686 questions processed
#   Batch 1910/3343 — 3820/6686 questions processed
#   Batch 1920/3343 — 3840/6686 questions processed
#   Batch 1930/3343 — 3860/6686 questions processed
#   Batch 1940/3343 — 3880/6686 questions processed
#   Batch 1950/3343 — 3900/6686 questions processed
#   Batch 1960/3343 — 3920/6686 questions processed
#   Batch 1970/3343 — 3940/6686 questions processed
#   Batch 1980/3343 — 3960/6686 questions processed
#   Batch 1990/3343 — 3980/6686 questions processed
#   Batch 2000/3343 — 4000/6686 questions processed
#   Batch 2010/3343 — 4020/6686 questions processed
#   Batch 2020/3343 — 4040/6686 questions processed
#   Batch 2030/3343 — 4060/6686 questions processed
#   Batch 2040/3343 — 4080/6686 questions processed
#   Batch 2050/3343 — 4100/6686 questions processed
#   Batch 2060/3343 — 4120/6686 questions processed
#   Batch 2070/3343 — 4140/6686 questions processed
#   Batch 2080/3343 — 4160/6686 questions processed
#   Batch 2090/3343 — 4180/6686 questions processed
#   Batch 2100/3343 — 4200/6686 questions processed
#   Batch 2110/3343 — 4220/6686 questions processed
#   Batch 2120/3343 — 4240/6686 questions processed
#   Batch 2130/3343 — 4260/6686 questions processed
#   Batch 2140/3343 — 4280/6686 questions processed
#   Batch 2150/3343 — 4300/6686 questions processed
#   Batch 2160/3343 — 4320/6686 questions processed
#   Batch 2170/3343 — 4340/6686 questions processed
#   Batch 2180/3343 — 4360/6686 questions processed
#   Batch 2190/3343 — 4380/6686 questions processed
#   Batch 2200/3343 — 4400/6686 questions processed
#   Batch 2210/3343 — 4420/6686 questions processed
#   Batch 2220/3343 — 4440/6686 questions processed
#   Batch 2230/3343 — 4460/6686 questions processed
#   Batch 2240/3343 — 4480/6686 questions processed
#   Batch 2250/3343 — 4500/6686 questions processed
#   Batch 2260/3343 — 4520/6686 questions processed
#   Batch 2270/3343 — 4540/6686 questions processed
#   Batch 2280/3343 — 4560/6686 questions processed
#   Batch 2290/3343 — 4580/6686 questions processed
#   Batch 2300/3343 — 4600/6686 questions processed
#   Batch 2310/3343 — 4620/6686 questions processed
#   Batch 2320/3343 — 4640/6686 questions processed
#   Batch 2330/3343 — 4660/6686 questions processed
#   Batch 2340/3343 — 4680/6686 questions processed
#   Batch 2350/3343 — 4700/6686 questions processed
#   Batch 2360/3343 — 4720/6686 questions processed
#   Batch 2370/3343 — 4740/6686 questions processed
#   Batch 2380/3343 — 4760/6686 questions processed
#   Batch 2390/3343 — 4780/6686 questions processed
#   Batch 2400/3343 — 4800/6686 questions processed
#   Batch 2410/3343 — 4820/6686 questions processed
#   Batch 2420/3343 — 4840/6686 questions processed
#   Batch 2430/3343 — 4860/6686 questions processed
#   Batch 2440/3343 — 4880/6686 questions processed
#   Batch 2450/3343 — 4900/6686 questions processed
#   Batch 2460/3343 — 4920/6686 questions processed
#   Batch 2470/3343 — 4940/6686 questions processed
#   Batch 2480/3343 — 4960/6686 questions processed
#   Batch 2490/3343 — 4980/6686 questions processed
#   Batch 2500/3343 — 5000/6686 questions processed
#   Batch 2510/3343 — 5020/6686 questions processed
#   Batch 2520/3343 — 5040/6686 questions processed
#   Batch 2530/3343 — 5060/6686 questions processed
#   Batch 2540/3343 — 5080/6686 questions processed
#   Batch 2550/3343 — 5100/6686 questions processed
#   Batch 2560/3343 — 5120/6686 questions processed
#   Batch 2570/3343 — 5140/6686 questions processed
#   Batch 2580/3343 — 5160/6686 questions processed
#   Batch 2590/3343 — 5180/6686 questions processed
#   Batch 2600/3343 — 5200/6686 questions processed
#   Batch 2610/3343 — 5220/6686 questions processed
#   Batch 2620/3343 — 5240/6686 questions processed
#   Batch 2630/3343 — 5260/6686 questions processed
#   Batch 2640/3343 — 5280/6686 questions processed
#   Batch 2650/3343 — 5300/6686 questions processed
#   Batch 2660/3343 — 5320/6686 questions processed
#   Batch 2670/3343 — 5340/6686 questions processed
#   Batch 2680/3343 — 5360/6686 questions processed
#   Batch 2690/3343 — 5380/6686 questions processed
#   Batch 2700/3343 — 5400/6686 questions processed
#   Batch 2710/3343 — 5420/6686 questions processed
#   Batch 2720/3343 — 5440/6686 questions processed
#   Batch 2730/3343 — 5460/6686 questions processed
#   Batch 2740/3343 — 5480/6686 questions processed
#   Batch 2750/3343 — 5500/6686 questions processed
#   Batch 2760/3343 — 5520/6686 questions processed
#   Batch 2770/3343 — 5540/6686 questions processed
#   Batch 2780/3343 — 5560/6686 questions processed
#   Batch 2790/3343 — 5580/6686 questions processed
#   Batch 2800/3343 — 5600/6686 questions processed
#   Batch 2810/3343 — 5620/6686 questions processed
#   Batch 2820/3343 — 5640/6686 questions processed
#   Batch 2830/3343 — 5660/6686 questions processed
#   Batch 2840/3343 — 5680/6686 questions processed
#   Batch 2850/3343 — 5700/6686 questions processed
#   Batch 2860/3343 — 5720/6686 questions processed
#   Batch 2870/3343 — 5740/6686 questions processed
#   Batch 2880/3343 — 5760/6686 questions processed
#   Batch 2890/3343 — 5780/6686 questions processed
#   Batch 2900/3343 — 5800/6686 questions processed
#   Batch 2910/3343 — 5820/6686 questions processed
#   Batch 2920/3343 — 5840/6686 questions processed
#   Batch 2930/3343 — 5860/6686 questions processed
#   Batch 2940/3343 — 5880/6686 questions processed
#   Batch 2950/3343 — 5900/6686 questions processed
#   Batch 2960/3343 — 5920/6686 questions processed
#   Batch 2970/3343 — 5940/6686 questions processed
#   Batch 2980/3343 — 5960/6686 questions processed
#   Batch 2990/3343 — 5980/6686 questions processed
#   Batch 3000/3343 — 6000/6686 questions processed
#   Batch 3010/3343 — 6020/6686 questions processed
#   Batch 3020/3343 — 6040/6686 questions processed
#   Batch 3030/3343 — 6060/6686 questions processed
#   Batch 3040/3343 — 6080/6686 questions processed
#   Batch 3050/3343 — 6100/6686 questions processed
#   Batch 3060/3343 — 6120/6686 questions processed
#   Batch 3070/3343 — 6140/6686 questions processed
#   Batch 3080/3343 — 6160/6686 questions processed
#   Batch 3090/3343 — 6180/6686 questions processed
#   Batch 3100/3343 — 6200/6686 questions processed
#   Batch 3110/3343 — 6220/6686 questions processed
#   Batch 3120/3343 — 6240/6686 questions processed
#   Batch 3130/3343 — 6260/6686 questions processed
#   Batch 3140/3343 — 6280/6686 questions processed
#   Batch 3150/3343 — 6300/6686 questions processed
#   Batch 3160/3343 — 6320/6686 questions processed
#   Batch 3170/3343 — 6340/6686 questions processed
#   Batch 3180/3343 — 6360/6686 questions processed
#   Batch 3190/3343 — 6380/6686 questions processed
#   Batch 3200/3343 — 6400/6686 questions processed
#   Batch 3210/3343 — 6420/6686 questions processed
#   Batch 3220/3343 — 6440/6686 questions processed
#   Batch 3230/3343 — 6460/6686 questions processed
#   Batch 3240/3343 — 6480/6686 questions processed
#   Batch 3250/3343 — 6500/6686 questions processed
#   Batch 3260/3343 — 6520/6686 questions processed
#   Batch 3270/3343 — 6540/6686 questions processed
#   Batch 3280/3343 — 6560/6686 questions processed
#   Batch 3290/3343 — 6580/6686 questions processed
#   Batch 3300/3343 — 6600/6686 questions processed
#   Batch 3310/3343 — 6620/6686 questions processed
#   Batch 3320/3343 — 6640/6686 questions processed
#   Batch 3330/3343 — 6660/6686 questions processed
#   Batch 3340/3343 — 6680/6686 questions processed
#   Batch 3343/3343 — 6686/6686 questions processed
#
# 📊 Fine-tuned LLM — Validation ROUGE Scores
#    ROUGE-1 F1 : 0.1306
#    ROUGE-L F1 : 0.1109
#
# 📊 ROUGE scores by language (fine-tuned model):
#          rouge1_f1  rougeL_f1
# Aka_Gha     0.2063     0.1622
# Amh_Eth     0.0695     0.0665
# Eng_Eth     0.2624     0.2533
# Eng_Gha     0.1817     0.1547
# Eng_Ken     0.0828     0.0677
# Eng_Uga     0.0808     0.0634
# Lug_Uga     0.0738     0.0654
# Swa_Ken     0.0607     0.0533
# Saving fine-tuned submission...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_108/3756928035.py in <cell line: 0>()
#      41 # ── Save fine-tuned submission ─────────────────────────────────────────────
#      42 print('\nSaving fine-tuned submission...')
# ---> 43 sub_finetuned = make_submission(
#      44     ids         = test[TEST_ID_COL].values,
#      45     predictions = test_pred_finetuned,
#
# /tmp/ipykernel_108/2264482841.py in make_submission(ids, predictions, output_path)
#      33         'TargetRLF1 and TargetLLM differ'
#      34
# ---> 35     sub.to_csv(output_path, index=False, encoding='utf-8')
#      36     print(f'✅ Submission saved to: {output_path}')
#      37     print(f'   Shape : {sub.shape}')
#
# /usr/local/lib/python3.12/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3987         )
#    3988
# -> 3989         return DataFrameRenderer(formatter).to_csv(
#    3990             path_or_buf,
#    3991             lineterminator=lineterminator,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in save(self)
#     268             )
#     269
# --> 270             self._save()
#     271
#     272     def _save(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     273         if self._need_to_save_header:
#     274             self._save_header()
# --> 275         self._save_body()
#     276
#     277     def _save_header(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     311             if start_i >= end_i:
#     312                 break
# --> 313             self._save_chunk(start_i, end_i)
#     314
#     315     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     322
#     323         ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
# --> 324         libwriters.write_csv_rows(
#     325             data,
#     326             ix,
#
# pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# OSError: [Errno 28] No space left on device

# %%
import shutil
shutil.rmtree('./mt5-small-exp4-epochs5', ignore_errors=True)
print('Checkpoint deleted')
# Out:
# Checkpoint deleted

# %%
from pathlib import Path

OUTPUT_FINETUNED = Path('/kaggle/working/submission_exp4_mt5small_epochs5.csv')

sub_finetuned = make_submission(
    ids         = test[TEST_ID_COL].values,
    predictions = test_pred_finetuned,
    output_path = OUTPUT_FINETUNED,
)
# Out:
# ✅ Submission saved to: /kaggle/working/submission_exp4_mt5small_epochs5.csv
#    Shape : (2618, 4)
#                        ID  \
# 0  ID_TS_Aka_Gha_A3B1799D
# 1  ID_TS_Aka_Gha_1C80317F
# 2  ID_TS_Aka_Gha_06671AD1
#
#                                                                                               TargetRLF1  \
# 0         This is a ɛbɛyɛ nkyerɛkyerɛ nneɛma, adwumayɛbea ahorow, ne akuo ahorow a wɔde bɛhwehwɛ nnaɛma.
# 1  This is a ɛfa hokwan a mmabun wɔ sɛ wonya nipadua mu ahofadi wɔ nna ne awoɔ akwahosan ho nhyehyɛe mu.
# 2                      This is a ɛfa nnipa a wɔbɛgyina ho kɛkɛ 'bystander' wɔ bere a asɛm bi mu ayɛ den.
#
#                                                                                               TargetR1F1  \
# 0         This is a ɛbɛyɛ nkyerɛkyerɛ nneɛma, adwumayɛbea ahorow, ne akuo ahorow a wɔde bɛhwehwɛ nnaɛma.
# 1  This is a ɛfa hokwan a mmabun wɔ sɛ wonya nipadua mu ahofadi wɔ nna ne awoɔ akwahosan ho nhyehyɛe mu.
# 2                      This is a ɛfa nnipa a wɔbɛgyina ho kɛkɛ 'bystander' wɔ bere a asɛm bi mu ayɛ den.
#
#                                                                                                TargetLLM
# 0         This is a ɛbɛyɛ nkyerɛkyerɛ nneɛma, adwumayɛbea ahorow, ne akuo ahorow a wɔde bɛhwehwɛ nnaɛma.
# 1  This is a ɛfa hokwan a mmabun wɔ sɛ wonya nipadua mu ahofadi wɔ nna ne awoɔ akwahosan ho nhyehyɛe mu.
# 2                      This is a ɛfa nnipa a wɔbɛgyina ho kɛkɛ 'bystander' wɔ bere a asɛm bi mu ayɛ den.
